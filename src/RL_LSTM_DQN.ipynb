# %%
import pandas as pd
from keras.models import Sequential, Model
import keras.layers as layers
from keras.optimizers import Adam
from keras import backend as K
import numpy as np
import random
import os
import pdb
import matplotlib.pyplot as plt
from copy import deepcopy
import tensorflow as tf
import time
from tensorflow.python.client import device_lib
import sys
import keras
 
print("TF INFO:", device_lib.list_local_devices())
print('GPU INFO:', K.tensorflow_backend._get_available_gpus())

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.9
K.set_session(tf.Session(config=config))
K.tensorflow_backend.set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/fahmid/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# TF INFO: [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6510251721243927723
# ]
# GPU INFO: []

# %% [markdown]
# # DQN Algorithm

# %%
class DQNAgent:
    def __init__(self, df_batch, state_size, action_size,
                 minibatch_size=128, gamma=.95, lr=0.001, units=128, priority_aplha = 0.5, 
                 lookback=3, is_lstm=False, layers=4, bcq=0,
                 copy_online_to_target_ep=100, eval_after=100, mode="normal"):
        """
        creates a DQN Agent for batch learning
        param: df_batch is the batch data in MDP format
        param: state_size
        param: action_size
        param: minibatch_size 
        param: gamma
        param: lr
        param: units
        param: priority_aplha for Prioritized Experience Reply. 0 Makes it Vanilla Experience Reply
        param: copy_online_to_target_ep copies current network to terget network. meaningless for Double DQN
        param: eval_after 
        param: lookback how many historical states are inluced including the current one
        param: is_lstm is for layer type
        param: layers is for number of layers including output layer
        param: mode is for baselines. normal is no baseline. other options are: random, 0, 1, 2, 3
        
        """
        
        #adding priority as noise in batch
        df_batch.at[:, 'weight'] = 0.0
        for i, row in df_batch.iterrows():
            df_batch.at[i, 'priority'] = (np.random.uniform(0, 0.001))**priority_aplha
        
        # setting parameters
        self.state_size = state_size
        self.action_size = action_size
        self.batch = df_batch
        
        self.minibatch_size = minibatch_size
        self.gamma = gamma
        self.learning_rate = lr
        self.units = units
        self.priority_aplha = priority_aplha
        self.lookback = lookback
        self.is_lstm = is_lstm
        self.layers = layers
        if self.layers<3:
            print("MIN LAYERS SHOULD BE 3. FORCING 3 LAYERS (including output)")
            self.layers = 3
        self.bcq = bcq
        
        self.copy_online_to_target_ep = copy_online_to_target_ep
        self.eval_after = eval_after
        
        self.batch = self._setup_lookback_states(self.batch)
        
        self.mode = mode
        
        # setting up the models
        self.model_1 = self._build_model()
        self.model_2 = self._build_model()
        
        
        # evaluation variables
        self.ecrs = []
        self.IS = []
        self.WIS = []
        self.PDIS = []
        self.PDWIS = []
        self.DR = []
        self.remediations = []
    
    
    def _setup_lookback_states(self, df):
        curr_ep = -1
        for i, row in df.iterrows():
            if curr_ep!=row['episode_id']:
                curr_ep = row['episode_id']
                prevs = []
                for j in range(self.lookback-1):
                    prevs.append(np.full(shape=self.state_size, fill_value=0))
                state = row['state'] 
                prevs.append(state)
                pervs = deepcopy(prevs)
            df.at[i, 'state'] = np.array(prevs)
            prevs = deepcopy(prevs[1:])
            prevs.append(row['next_state'])
            pervs = deepcopy(prevs)
            df.at[i, 'next_state'] = np.array(prevs)
            prevs = deepcopy(prevs)    
        
        for i, row in df.iterrows():
            state, next_state = self.get_transformed_state(row)
            df.at[i, 'state'] = state
            df.at[i, 'next_state'] = next_state
        
        
        return df
    
    def get_transformed_state(self, row):
        if self.is_lstm:
            state = row['state'].reshape(1, self.lookback, self.state_size)
            next_state = row['next_state'].reshape(1, self.lookback, self.state_size)
        else:
            state = row['state'].reshape(1, self.state_size * self.lookback)
            next_state = row['next_state'].reshape(1, self.state_size * self.lookback)
        
        return state, next_state
    
    def _build_model(self):
        """
        Standard DQN model
        """
        model = Sequential()
        
        if self.is_lstm:
            # 1 layer
            model.add(layers.LSTM(self.units, input_shape=(self.lookback, self.state_size), 
                                  activation='relu', kernel_regularizer=keras.regularizers.l2(), 
                                  return_sequences=True, kernel_initializer='glorot_normal'))
            
            for i in range(self.layers-3):
                model.add(layers.LSTM(self.units, activation='relu', kernel_regularizer=keras.regularizers.l2(), 
                                      return_sequences=True, kernel_initializer='glorot_normal'))
            # 1 layer
            model.add(layers.LSTM(self.units, activation='relu', kernel_regularizer=keras.regularizers.l2(), 
                                  return_sequences=False, kernel_initializer='glorot_normal'))
        else:
            model.add(layers.Dense(self.units, input_dim=self.state_size * self.lookback, activation='relu', 
                                   kernel_regularizer=keras.regularizers.l2(), kernel_initializer='glorot_normal'))
            for i in range(self.layers-2):
                model.add(layers.Dense(self.units, activation='relu', 
                                       kernel_regularizer=keras.regularizers.l2(), kernel_initializer='glorot_normal'))
            
        # 1 layer
        model.add(layers.Dense(self.action_size, activation='linear', 
                               kernel_regularizer=keras.regularizers.l2(), kernel_initializer='glorot_normal'))
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate), metrics=[tf.keras.metrics.RootMeanSquaredError(), 'mae'])
        return model
    
    def act(self, state):
        act_values = self.model_2.predict(state)
        return np.argmax(act_values[0]), np.max(act_values[0])
    
    def state_value(self, state):
        act_values = self.model_2.predict(state)
        return np.sum(act_values[0]) 
    
    def q_value(self, state, action):
        act_values = self.model_2.predict(state)
        return act_values[0][action] 
    
    def _filter_bcq(self, row, ns_act_values):
        if self.bcq==0:
            return np.argmax(ns_act_values)
        
        gw = self.batch.loc[self.batch['cluster']==row['ns_cluster']].sample(100)
        gwa = gw.groupby(['action']).count()['episode_id'].tolist()
        gwap = np.array(gwa)/100
        
        for i, p in enumerate(gwap):
            if p<self.bcq:
                ns_act_values[i] = -9999
        
        return np.argmax(ns_act_values)
    
    def _fit_model(self, row):
        i = row.name
        state, action, reward, next_state, done = row['state'], row['action'], row['reward'], row['next_state'], row['done']
            
        target_q = reward
        
        if not done:    
            if self.mode=="normal":
                ns_act_values = self.model_1.predict(next_state)[0]
#                 a_prime = np.argmax(ns_act_values)
                a_prime = self._filter_bcq(row, ns_act_values)
            elif self.mode=="random":
                a_prime = np.random.choice(range(self.action_size))
            else:
                a_prime = int(self.mode)
            
            target_ns_act_values = self.model_2.predict(next_state)[0]
            target_ns_q = target_ns_act_values[a_prime]
                           

            target_q = reward + self.gamma*target_ns_q

            self.batch.loc[i, 'pred_action'] = a_prime
            self.batch.loc[i, 'pred_q'] = target_q
        
        target_f = self.model_1.predict(state)

        # Prioritized Experience Reply with noise
        
        self.batch.loc[i, 'priority'] = (abs(target_q - target_f[0][action]) + np.random.uniform(0, 0.001))**self.priority_aplha

        target_f[0][action] = target_q
        self.model_1.fit(state, target_f, epochs=1, verbose=0)
        
    
    def _learn_minibatch(self):
        priority_sum = self.batch['priority'].sum()
        self.batch['weight'] = self.batch['priority']/priority_sum
        minibatch = self.batch.sample(self.minibatch_size, weights=self.batch['weight'])
        minibatch.apply(self._fit_model, axis=1) 
            
    
    def ecr_reward(self):
        reward = 0.0
        count = 0
        for i, row in self.batch.loc[self.batch['transition_id']==0].iterrows():
            state = row['state']
            reward += self.act(state)[1]
            count += 1
            
        ecr = reward/count
        self.ecrs.append(ecr)
        return ecr

    
    def get_ips(self, action):
        if self.action_size==2:
            ips = 1.0/0.5
        else:
            if action == 0 or action == 1:
                ips = 1.0/0.1
            else:
                ips = 1.0/0.4
        return ips
        
    
    
    def get_eval(self):
        # set up roh with action_predicted
        self.batch['roh'] = -1.0
        curr_ep = -1
        for i, row in self.batch.iterrows():
            if row['episode_id']!=curr_ep:
                roh_t = 1
                curr_ep = row['episode_id']
            if row['action']!=row['pred_action']:
                ips = 0
            else:
                ips = self.get_ips(row['action'])
                
            roh_t *= ips
            self.batch.at[i, 'roh'] = roh_t
        
        total_eps = len(self.batch['episode_id'].unique())
        # equation found in emma brunskill's lecture note
        
        # as each roh is calculated multiplicatively, the last roh is the entire multiplication result
        # summing (gamma**t)*(R_t^i) will result to delayed reward
        # we can take the last roh (where done is true) and the delayed reward for each ep
        a_is = sum(self.batch.loc[self.batch['done']==True].apply(lambda x: x['roh'] * x['delayed_reward'], axis=1))
        isamp = a_is/total_eps
        
        # for weighted important samplng
        sum_roh = sum(self.batch.loc[self.batch['done']==True, 'roh'])
        if sum_roh==0:
            wis = 0
        else:
            wis = a_is/sum_roh
        
        pdis = 0
        for transition_id in self.batch['transition_id'].unique():
            d = self.batch.loc[self.batch['transition_id']==transition_id]
            a_pdis = (self.gamma**transition_id) * sum(d.apply(lambda x: x['roh'] * x['reward'], axis=1))
            pdis += (a_pdis/total_eps)
        
        curr_ep = -1
        trans = -1
        dr = 0
        pdwis = 0
        pdwis_nom = 0
        pdwis_denom = 0
        for i, row in self.batch.iterrows():
            if curr_ep!=row['episode_id']:
                curr_ep = row['episode_id']
                trans = 0
            if row['transition_id']!=trans:
                print("ERROR:", curr_ep, row['transition_id'], trans)
            
            gamma_t = self.gamma**row['transition_id']
            q_pi_e = self.q_value(row['state'], row['action'])
            v_pi_e = self.state_value(row['state'])
            roh_t_i = row['roh']
            if trans!=0:
                roh_t_sub_1_i = self.batch.loc[(self.batch['episode_id']==row['episode_id']) &
                                                  (self.batch['transition_id']==(trans-1)), 'roh'].tolist()[0]
            else:
                roh_t_sub_1_i = 1
            
            dr += ((gamma_t*roh_t_i*(row['reward'] - q_pi_e)) + (gamma_t*roh_t_sub_1_i*v_pi_e))
            
            # PDWIS
            sum_roh_t = float(sum(self.batch.loc[self.batch['transition_id']==row['transition_id']]['roh']))
            if sum_roh_t==0:
                w_t_i = 0
            else:
                w_t_i = row['roh']/sum_roh_t
            pdwis_nom += (w_t_i * gamma_t * row['reward'])
            pdwis_denom += (w_t_i * gamma_t)
            
            trans += 1
        
        dr = dr/total_eps
        pdwis = pdwis_nom/pdwis_denom
        
        
        self.IS.append(isamp)
        self.WIS.append(wis)
        self.PDIS.append(pdis)
        self.PDWIS.append(pdwis)
        self.DR.append(dr)
        
        return isamp, wis, pdis, pdwis, dr
        
    
    def predict(self):
        self.batch['pred_action'] = -1
        self.batch['pred_q'] = 0
        self.batch.apply(self._predict_row, axis=1)
    
    def _predict_row(self, row):
        i = row.name
        state = row['state']
        act, q = self.act(state)
        self.batch.loc[i, 'pred_action'] = act
        self.batch.loc[i, 'pred_q'] = q
    
    def learn(self, epoch):
        for i in range(epoch):
            self._learn_minibatch()
            
            if (i+1)%self.copy_online_to_target_ep==0:
                self.model_2.set_weights(self.model_1.get_weights())
            
            if (i+1)%self.eval_after==0:
                t1 = time.time()
                self.predict()
                
                ecr = self.ecr_reward()
                isamp, wis, pdis, pdwis, dr = self.get_eval()
                t2 = time.time()
                print("Eval Time:", (t2-t1))
                print("--epoch: {}/{} | ECR: {:.5f} | IS: {:.5f} | WIS: {:.5f} | PDIS: {:.5f} | PDWIS: {:.5f} | DR: {:.5f} --".format(i+1, epoch, ecr, isamp, wis, pdis, pdwis, dr))
                self.summary()
        
        self.model_2.set_weights(self.model_1.get_weights())
        self.predict()
                
    
    def get_all_eval_df(self):
        eval_df = pd.DataFrame(columns=['ECR', 'IS', 'WIS', 'PDIS', 'PDWIS', 'DR', 'REMEDIATION'])
        
        eval_df['ECR'] = self.ecrs
        eval_df['IS'] = self.IS
        eval_df['WIS'] = self.WIS
        eval_df['PDIS'] = self.PDIS
        eval_df['PDWIS'] = self.PDWIS
        eval_df['DR'] = self.DR
        eval_df['REMEDIATION'] = self.remediations
        
        return eval_df
    
    
    def summary(self):
        pred_const = len(self.batch.loc[self.batch['pred_action'] == 3]) 
        pred_active = len(self.batch.loc[self.batch['pred_action'] == 2])
        pred_pass = len(self.batch.loc[self.batch['pred_action'] == 1])
        pred_none = len(self.batch.loc[self.batch['pred_action'] == 0])

        self.remediations.append({"constructive": pred_const, "active": pred_active, "passive": pred_pass,
                                "none": pred_none})
        print("Pred-> Constructive: {}, Active: {}, Passive: {}, None: {}"
              .format(pred_const, pred_active, pred_pass, pred_none))

# %% [markdown]
# # Result

# %%
def summary_result(df):

    true_const = len(df.loc[df['action'] == 3])
    true_active = len(df.loc[df['action'] == 2])
    true_pass = len(df.loc[df['action'] == 1])
    true_none = len(df.loc[df['action'] == 0])
    
    pred_const = len(df.loc[df['pred_action'] == 3]) 
    pred_active = len(df.loc[df['pred_action'] == 2])
    pred_pass = len(df.loc[df['pred_action'] == 1])
    pred_none = len(df.loc[df['pred_action'] == 0])
     
    
    print("True-> Constructive: {}, Active: {}, Passive: {}, None: {}"
          .format(true_const, true_active, true_pass, true_none))
    print("Pred-> Constructive: {}, Active: {}, Passive: {}, None: {}"
          .format(pred_const, pred_active, pred_pass, pred_none))
    
    
    
    true_reward = df.loc[df['done']==True]['reward']
    pred_reward = df.loc[df['transition_id']==0]['pred_q']
    true_reward_mean = np.mean(true_reward)
    true_reward_std = np.std(true_reward)
    pred_reward_mean = np.mean(pred_reward)
    pred_reward_std = np.std(pred_reward)
    
    print("-> True Reward: {:.5f}/{:.5f}, Pred Reward: {:.5f}/{:.5f}".format(
        true_reward_mean, true_reward_std, pred_reward_mean, pred_reward_std))

    
    ret_dict = {"True": {"Constructive": true_const, "Active": true_active, "Passive": true_pass, 
                         "None": true_none, "RewardMean": true_reward_mean, "RewardStd": true_reward_std},
               "Pred": {"Constructive": pred_const, "Active": pred_active, "Passive": pred_pass, 
                         "None": pred_none, "RewardMean": pred_reward_mean, "RewardStd": pred_reward_std}
               }
    
    
    
    return ret_dict

# %% [markdown]
# # Run Program

# %%
df_org = pd.read_pickle('../temp/df_all_norm_cluster.pkl')
df = df_org.copy()
epoch = 20000
df['reward'] = df['delayed_reward']
result_dir = '../result/'
def run(agent, run_name, epoch):
    print("===== STARTING ", run_name, "=====")
    agent.learn(epoch)
    result_df = agent.batch
    eval_df = agent.get_all_eval_df()
    eval_df.to_pickle(result_dir + run_name +'_eval.pkl')
    summary_result(result_df)
    result_df.to_pickle(result_dir + run_name +'_result.pkl')

    return result_df, eval_df

for is_lstm in [True]:
    for lookback in [1]:
        for random_state in [1,2,3,4,5]:
            np.random.seed(random_state)
            random.seed(random_state)
            tf.set_random_seed(random_state)
            print("TF INFO:", device_lib.list_local_devices())
            print('GPU INFO:', K.tensorflow_backend._get_available_gpus())

            config = tf.ConfigProto(log_device_placement=True)
            config.gpu_options.per_process_gpu_memory_fraction = 0.9
            K.set_session(tf.Session(config=config))
            K.tensorflow_backend.set_session(tf.Session(config=config))

            
            run_name = "DQN_is_lstm_"+ str(is_lstm) + "_lookback_" + str(lookback) + "_run_" + str(epoch) + "_rs_" + str(random_state)
            agent = DQNAgent(df_batch=df.copy(), state_size=len(df.iloc[0]['state']), action_size=4, 
                             copy_online_to_target_ep=100, eval_after=100, bcq=0.1,
                             lookback=lookback, layers=4, is_lstm=is_lstm, mode="normal")
            result_df, eval_df = run(agent, run_name, epoch)
# Out:
# TF INFO: [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1448305049376309946
# ]
# GPU INFO: []
# ===== STARTING  DQN_is_lstm_True_lookback_1_run_20000_rs_1 =====
# Eval Time: 23.228199243545532
# --epoch: 100/20000 | ECR: 5.71830 | IS: 1.62567 | WIS: 63.33600 | PDIS: 1.62567 | PDWIS: 0.52367 | DR: 54.08142 --
# Pred-> Constructive: 795, Active: 0, Passive: 1341, None: 2862
# Eval Time: 23.105072259902954
# --epoch: 200/20000 | ECR: 13.42545 | IS: 1.36899 | WIS: 66.67000 | PDIS: 1.36899 | PDWIS: 0.51939 | DR: 147.72490 --
# Pred-> Constructive: 0, Active: 0, Passive: 1571, None: 3427
# Eval Time: 23.135251998901367
# --epoch: 300/20000 | ECR: 16.08883 | IS: 11.54320 | WIS: 63.34127 | PDIS: 10.96524 | PDWIS: 8.09803 | DR: 186.97350 --
# Pred-> Constructive: 2029, Active: 0, Passive: 2969, None: 0
# Eval Time: 23.255128145217896
# --epoch: 400/20000 | ECR: 23.15277 | IS: 13.94529 | WIS: 60.70486 | PDIS: 13.19203 | PDWIS: 4.91045 | DR: 278.71897 --
# Pred-> Constructive: 1821, Active: 424, Passive: 2753, None: 0
# Eval Time: 23.25309991836548
# --epoch: 500/20000 | ECR: 27.30527 | IS: 20.34737 | WIS: 53.29301 | PDIS: 19.06611 | PDWIS: 4.24426 | DR: 429.30141 --
# Pred-> Constructive: 2773, Active: 365, Passive: 1860, None: 0
# Eval Time: 23.275280952453613
# --epoch: 600/20000 | ECR: 31.12726 | IS: 16.35264 | WIS: 63.07911 | PDIS: 15.31083 | PDWIS: 7.31440 | DR: 333.38917 --
# Pred-> Constructive: 0, Active: 2575, Passive: 2423, None: 0
# Eval Time: 23.29206919670105
# --epoch: 700/20000 | ECR: 34.38797 | IS: 24.82359 | WIS: 60.44545 | PDIS: 22.84140 | PDWIS: 6.28976 | DR: 407.71175 --
# Pred-> Constructive: 2911, Active: 666, Passive: 1421, None: 0
# Eval Time: 23.445396900177002
# --epoch: 800/20000 | ECR: 36.00643 | IS: 25.89296 | WIS: 56.83323 | PDIS: 23.80650 | PDWIS: 5.14341 | DR: 525.00624 --
# Pred-> Constructive: 3447, Active: 0, Passive: 1551, None: 0
# Eval Time: 24.62351703643799
# --epoch: 900/20000 | ECR: 41.12932 | IS: 25.89296 | WIS: 56.83323 | PDIS: 23.80650 | PDWIS: 5.44228 | DR: 547.31486 --
# Pred-> Constructive: 3684, Active: 0, Passive: 1314, None: 0
# Eval Time: 24.707538843154907
# --epoch: 1000/20000 | ECR: 44.26351 | IS: 15.12631 | WIS: 66.96830 | PDIS: 14.14867 | PDWIS: 3.15247 | DR: 714.68775 --
# Pred-> Constructive: 0, Active: 3900, Passive: 1098, None: 0
# Eval Time: 23.901106119155884
# --epoch: 1100/20000 | ECR: 47.20622 | IS: 25.89296 | WIS: 55.88863 | PDIS: 23.80650 | PDWIS: 6.03584 | DR: 610.45982 --
# Pred-> Constructive: 3211, Active: 0, Passive: 1787, None: 0
# Eval Time: 23.657355070114136
# --epoch: 1200/20000 | ECR: 43.77087 | IS: 15.12631 | WIS: 64.76055 | PDIS: 14.14867 | PDWIS: 3.18592 | DR: 668.77259 --
# Pred-> Constructive: 0, Active: 3240, Passive: 1758, None: 0
# Eval Time: 23.415622234344482
# --epoch: 1300/20000 | ECR: 45.35949 | IS: 25.89296 | WIS: 55.88863 | PDIS: 23.80650 | PDWIS: 5.62646 | DR: 594.37569 --
# Pred-> Constructive: 3703, Active: 0, Passive: 1295, None: 0
# Eval Time: 23.490190029144287
# --epoch: 1400/20000 | ECR: 39.47457 | IS: 15.06928 | WIS: 67.48264 | PDIS: 14.09163 | PDWIS: 2.87554 | DR: 656.22641 --
# Pred-> Constructive: 92, Active: 2978, Passive: 1805, None: 123
# Eval Time: 23.401674032211304
# --epoch: 1500/20000 | ECR: 43.30140 | IS: 15.12631 | WIS: 62.69372 | PDIS: 14.14867 | PDWIS: 3.14514 | DR: 721.08561 --
# Pred-> Constructive: 769, Active: 3208, Passive: 848, None: 173
# Eval Time: 23.701831817626953
# --epoch: 1600/20000 | ECR: 42.09403 | IS: 5.08450 | WIS: 52.12947 | PDIS: 4.87061 | PDWIS: 2.87649 | DR: 360.60298 --
# Pred-> Constructive: 0, Active: 19, Passive: 4543, None: 436
# Eval Time: 23.509955883026123
# --epoch: 1700/20000 | ECR: 41.43869 | IS: 15.12631 | WIS: 66.21584 | PDIS: 14.14867 | PDWIS: 2.96995 | DR: 655.07040 --
# Pred-> Constructive: 0, Active: 3018, Passive: 1754, None: 226
# Eval Time: 23.344166040420532
# --epoch: 1800/20000 | ECR: 44.44963 | IS: 71.34961 | WIS: 78.85904 | PDIS: 62.80442 | PDWIS: 25.77738 | DR: 427.40062 --
# Pred-> Constructive: 0, Active: 1802, Passive: 3120, None: 76
# Eval Time: 23.630749940872192
# --epoch: 1900/20000 | ECR: 43.81345 | IS: 23.48221 | WIS: 53.50098 | PDIS: 21.60715 | PDWIS: 6.82022 | DR: 540.18662 --
# Pred-> Constructive: 1682, Active: 0, Passive: 3194, None: 122
# Eval Time: 23.701451063156128
# --epoch: 2000/20000 | ECR: 44.07548 | IS: 15.36271 | WIS: 63.00326 | PDIS: 14.38506 | PDWIS: 2.66267 | DR: 726.16419 --
# Pred-> Constructive: 309, Active: 2554, Passive: 1966, None: 169
# Eval Time: 23.668269872665405
# --epoch: 2100/20000 | ECR: 44.11479 | IS: 24.58218 | WIS: 66.16385 | PDIS: 22.65213 | PDWIS: 5.92458 | DR: 613.80628 --
# Pred-> Constructive: 2824, Active: 0, Passive: 2142, None: 32
# Eval Time: 23.65103507041931
# --epoch: 2200/20000 | ECR: 42.15403 | IS: 15.28935 | WIS: 64.05086 | PDIS: 14.31171 | PDWIS: 2.94794 | DR: 694.93377 --
# Pred-> Constructive: 803, Active: 2731, Passive: 1340, None: 124
# Eval Time: 23.4900221824646
# --epoch: 2300/20000 | ECR: 43.61247 | IS: 26.94731 | WIS: 55.11114 | PDIS: 24.79381 | PDWIS: 5.73154 | DR: 640.64074 --
# Pred-> Constructive: 2575, Active: 905, Passive: 1082, None: 436
# Eval Time: 23.74375009536743
# --epoch: 2400/20000 | ECR: 46.86642 | IS: 26.18639 | WIS: 54.12317 | PDIS: 24.09993 | PDWIS: 5.78649 | DR: 673.34701 --
# Pred-> Constructive: 3182, Active: 0, Passive: 1416, None: 400
# Eval Time: 23.575159788131714
# --epoch: 2500/20000 | ECR: 47.14683 | IS: 15.06928 | WIS: 74.31633 | PDIS: 14.09163 | PDWIS: 2.87536 | DR: 844.20495 --
# Pred-> Constructive: 730, Active: 3270, Passive: 432, None: 566
# Eval Time: 23.41080117225647
# --epoch: 2600/20000 | ECR: 50.79894 | IS: 15.06928 | WIS: 74.31633 | PDIS: 14.09163 | PDWIS: 3.34989 | DR: 822.56402 --
# Pred-> Constructive: 0, Active: 3571, Passive: 1019, None: 408
# Eval Time: 23.55238699913025
# --epoch: 2700/20000 | ECR: 50.99275 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.60395 | DR: 713.45803 --
# Pred-> Constructive: 3943, Active: 0, Passive: 432, None: 623
# Eval Time: 23.42027711868286
# --epoch: 2800/20000 | ECR: 50.50689 | IS: 26.18639 | WIS: 64.87897 | PDIS: 24.09993 | PDWIS: 6.30566 | DR: 703.50497 --
# Pred-> Constructive: 3330, Active: 0, Passive: 1071, None: 597
# Eval Time: 23.507768154144287
# --epoch: 2900/20000 | ECR: 50.94902 | IS: 26.18639 | WIS: 64.87897 | PDIS: 24.09993 | PDWIS: 7.81942 | DR: 653.25546 --
# Pred-> Constructive: 2615, Active: 0, Passive: 2006, None: 377
# Eval Time: 23.447444915771484
# --epoch: 3000/20000 | ECR: 50.96059 | IS: 15.12631 | WIS: 66.96830 | PDIS: 14.14867 | PDWIS: 3.05442 | DR: 819.34292 --
# Pred-> Constructive: 0, Active: 4483, Passive: 143, None: 372
# Eval Time: 23.635498046875
# --epoch: 3100/20000 | ECR: 46.55707 | IS: 25.89296 | WIS: 56.83323 | PDIS: 23.80650 | PDWIS: 5.48317 | DR: 661.90301 --
# Pred-> Constructive: 4084, Active: 231, Passive: 346, None: 337
# Eval Time: 23.445362091064453
# --epoch: 3200/20000 | ECR: 45.34872 | IS: 15.12631 | WIS: 71.00253 | PDIS: 14.14867 | PDWIS: 3.17757 | DR: 776.27789 --
# Pred-> Constructive: 0, Active: 4006, Passive: 629, None: 363
# Eval Time: 23.73966693878174
# --epoch: 3300/20000 | ECR: 46.74865 | IS: 25.89296 | WIS: 56.83323 | PDIS: 23.80650 | PDWIS: 5.32526 | DR: 650.39336 --
# Pred-> Constructive: 4719, Active: 0, Passive: 0, None: 279
# Eval Time: 23.56502103805542
# --epoch: 3400/20000 | ECR: 46.35845 | IS: 25.89296 | WIS: 56.83323 | PDIS: 23.80650 | PDWIS: 5.32526 | DR: 674.40501 --
# Pred-> Constructive: 4201, Active: 463, Passive: 3, None: 331
# Eval Time: 23.54904007911682
# --epoch: 3500/20000 | ECR: 47.25177 | IS: 8.21099 | WIS: 56.12281 | PDIS: 7.87250 | PDWIS: 2.46727 | DR: 715.38603 --
# Pred-> Constructive: 1909, Active: 0, Passive: 2824, None: 265
# Eval Time: 23.610036849975586
# --epoch: 3600/20000 | ECR: 45.35045 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 684.69181 --
# Pred-> Constructive: 0, Active: 0, Passive: 4655, None: 343
# Eval Time: 23.633360147476196
# --epoch: 3700/20000 | ECR: 44.97754 | IS: 27.09620 | WIS: 58.16353 | PDIS: 24.84626 | PDWIS: 5.38134 | DR: 704.42252 --
# Pred-> Constructive: 2805, Active: 1624, Passive: 370, None: 199
# Eval Time: 23.439170122146606
# --epoch: 3800/20000 | ECR: 45.38105 | IS: 15.12631 | WIS: 66.96830 | PDIS: 14.14867 | PDWIS: 3.05442 | DR: 743.12265 --
# Pred-> Constructive: 0, Active: 4555, Passive: 347, None: 96
# Eval Time: 23.495348930358887
# --epoch: 3900/20000 | ECR: 44.86792 | IS: 6.79936 | WIS: 53.51576 | PDIS: 6.52196 | PDWIS: 25.51824 | DR: 357.53618 --
# Pred-> Constructive: 697, Active: 0, Passive: 4173, None: 128
# Eval Time: 23.504768133163452
# --epoch: 4000/20000 | ECR: 45.42400 | IS: 25.08642 | WIS: 64.19486 | PDIS: 23.05495 | PDWIS: 7.75403 | DR: 592.49287 --
# Pred-> Constructive: 2511, Active: 0, Passive: 2130, None: 357
# Eval Time: 23.716893911361694
# --epoch: 4100/20000 | ECR: 46.62831 | IS: 15.12631 | WIS: 66.96830 | PDIS: 14.14867 | PDWIS: 3.05442 | DR: 780.22356 --
# Pred-> Constructive: 0, Active: 4685, Passive: 106, None: 207
# Eval Time: 25.172689199447632
# --epoch: 4200/20000 | ECR: 43.18216 | IS: 37.16895 | WIS: 68.67112 | PDIS: 32.94580 | PDWIS: 10.70768 | DR: 580.60529 --
# Pred-> Constructive: 2088, Active: 1721, Passive: 0, None: 1189
# Eval Time: 23.509796857833862
# --epoch: 4300/20000 | ECR: 43.43054 | IS: 15.12631 | WIS: 71.00253 | PDIS: 14.14867 | PDWIS: 3.18752 | DR: 656.33333 --
# Pred-> Constructive: 0, Active: 4175, Passive: 0, None: 823
# Eval Time: 23.244649171829224
# --epoch: 4400/20000 | ECR: 43.31713 | IS: 23.79698 | WIS: 56.53233 | PDIS: 21.86978 | PDWIS: 5.96112 | DR: 612.48977 --
# Pred-> Constructive: 2538, Active: 1314, Passive: 628, None: 518
# Eval Time: 23.39764094352722
# --epoch: 4500/20000 | ECR: 45.43227 | IS: 25.94999 | WIS: 57.93764 | PDIS: 23.86353 | PDWIS: 5.65336 | DR: 627.78492 --
# Pred-> Constructive: 3589, Active: 111, Passive: 771, None: 527
# Eval Time: 23.260440826416016
# --epoch: 4600/20000 | ECR: 46.98065 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.75730 | DR: 649.79323 --
# Pred-> Constructive: 3431, Active: 391, Passive: 0, None: 1176
# Eval Time: 23.443187952041626
# --epoch: 4700/20000 | ECR: 45.66273 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 4.19800 | DR: 707.23248 --
# Pred-> Constructive: 3304, Active: 60, Passive: 205, None: 1429
# Eval Time: 23.22611379623413
# --epoch: 4800/20000 | ECR: 42.13242 | IS: 25.89296 | WIS: 57.81030 | PDIS: 23.80650 | PDWIS: 6.14700 | DR: 604.30493 --
# Pred-> Constructive: 2860, Active: 872, Passive: 19, None: 1247
# Eval Time: 23.277678966522217
# --epoch: 4900/20000 | ECR: 46.50764 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.76786 | DR: 646.35942 --
# Pred-> Constructive: 3403, Active: 0, Passive: 705, None: 890
# Eval Time: 26.86966300010681
# --epoch: 5000/20000 | ECR: 49.10280 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.53980 | DR: 668.45007 --
# Pred-> Constructive: 3672, Active: 0, Passive: 0, None: 1326
# Eval Time: 24.225569248199463
# --epoch: 5100/20000 | ECR: 49.33867 | IS: 25.89296 | WIS: 71.41874 | PDIS: 23.80650 | PDWIS: 5.97391 | DR: 675.45488 --
# Pred-> Constructive: 3115, Active: 658, Passive: 0, None: 1225
# Eval Time: 23.370112895965576
# --epoch: 5200/20000 | ECR: 53.47778 | IS: 15.12631 | WIS: 71.00253 | PDIS: 14.14867 | PDWIS: 3.16877 | DR: 803.25696 --
# Pred-> Constructive: 0, Active: 4270, Passive: 0, None: 728
# Eval Time: 23.362583875656128
# --epoch: 5300/20000 | ECR: 56.28887 | IS: 25.94999 | WIS: 69.60494 | PDIS: 23.86353 | PDWIS: 5.15126 | DR: 788.85672 --
# Pred-> Constructive: 2979, Active: 1164, Passive: 0, None: 855
# Eval Time: 23.402653217315674
# --epoch: 5400/20000 | ECR: 56.64938 | IS: 15.12631 | WIS: 72.75568 | PDIS: 14.14867 | PDWIS: 2.82523 | DR: 886.75964 --
# Pred-> Constructive: 50, Active: 3808, Passive: 3, None: 1137
# Eval Time: 23.442303895950317
# --epoch: 5500/20000 | ECR: 57.70860 | IS: 25.89296 | WIS: 71.41874 | PDIS: 23.80650 | PDWIS: 5.84479 | DR: 796.82979 --
# Pred-> Constructive: 3819, Active: 668, Passive: 3, None: 508
# Eval Time: 23.34397315979004
# --epoch: 5600/20000 | ECR: 54.97146 | IS: 28.69993 | WIS: 71.79128 | PDIS: 26.34535 | PDWIS: 5.81714 | DR: 762.88690 --
# Pred-> Constructive: 3385, Active: 607, Passive: 0, None: 1006
# Eval Time: 23.190910816192627
# --epoch: 5700/20000 | ECR: 51.38918 | IS: 15.12631 | WIS: 71.00253 | PDIS: 14.14867 | PDWIS: 2.84197 | DR: 857.55144 --
# Pred-> Constructive: 0, Active: 3937, Passive: 8, None: 1053
# Eval Time: 23.372480869293213
# --epoch: 5800/20000 | ECR: 52.95346 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.45229 | DR: 755.26912 --
# Pred-> Constructive: 3852, Active: 371, Passive: 533, None: 242
# Eval Time: 23.302435874938965
# --epoch: 5900/20000 | ECR: 55.09985 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.37356 | DR: 729.66761 --
# Pred-> Constructive: 4003, Active: 219, Passive: 14, None: 762
# Eval Time: 23.2832293510437
# --epoch: 6000/20000 | ECR: 51.34209 | IS: 2.07834 | WIS: 62.28615 | PDIS: 2.02219 | PDWIS: 0.75304 | DR: 845.74449 --
# Pred-> Constructive: 239, Active: 651, Passive: 3265, None: 843
# Eval Time: 25.620190858840942
# --epoch: 6100/20000 | ECR: 49.70384 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 642.11835 --
# Pred-> Constructive: 0, Active: 56, Passive: 4809, None: 133
# Eval Time: 25.401838064193726
# --epoch: 6200/20000 | ECR: 40.95755 | IS: 23.21939 | WIS: 77.81740 | PDIS: 21.39360 | PDWIS: 5.96266 | DR: 534.84719 --
# Pred-> Constructive: 2902, Active: 0, Passive: 14, None: 2082
# Eval Time: 23.354143857955933
# --epoch: 6300/20000 | ECR: 39.84480 | IS: 24.82359 | WIS: 75.11668 | PDIS: 22.84140 | PDWIS: 6.89266 | DR: 510.26289 --
# Pred-> Constructive: 3087, Active: 0, Passive: 18, None: 1893
# Eval Time: 23.28534507751465
# --epoch: 6400/20000 | ECR: 39.99397 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.44892 | DR: 560.81786 --
# Pred-> Constructive: 3769, Active: 271, Passive: 894, None: 64
# Eval Time: 23.31855320930481
# --epoch: 6500/20000 | ECR: 38.91734 | IS: 26.18639 | WIS: 56.52198 | PDIS: 24.09993 | PDWIS: 5.88609 | DR: 542.94674 --
# Pred-> Constructive: 3653, Active: 60, Passive: 1219, None: 66
# Eval Time: 23.183175086975098
# --epoch: 6600/20000 | ECR: 38.87236 | IS: 15.36271 | WIS: 68.79667 | PDIS: 14.38506 | PDWIS: 3.27687 | DR: 712.22779 --
# Pred-> Constructive: 2, Active: 2659, Passive: 2278, None: 59
# Eval Time: 23.672106981277466
# --epoch: 6700/20000 | ECR: 40.09632 | IS: 24.01705 | WIS: 66.95558 | PDIS: 22.08985 | PDWIS: 7.42525 | DR: 569.22580 --
# Pred-> Constructive: 2563, Active: 0, Passive: 2430, None: 5
# Eval Time: 23.166547060012817
# --epoch: 6800/20000 | ECR: 43.36581 | IS: 24.17485 | WIS: 69.89627 | PDIS: 22.23161 | PDWIS: 6.53291 | DR: 608.90221 --
# Pred-> Constructive: 2382, Active: 1496, Passive: 1050, None: 70
# Eval Time: 23.176236152648926
# --epoch: 6900/20000 | ECR: 45.06280 | IS: 0.35046 | WIS: 6.82700 | PDIS: 0.35046 | PDWIS: 0.14505 | DR: 609.30868 --
# Pred-> Constructive: 41, Active: 819, Passive: 4138, None: 0
# Eval Time: 23.169434070587158
# --epoch: 7000/20000 | ECR: 47.48451 | IS: 25.14345 | WIS: 66.07681 | PDIS: 23.11198 | PDWIS: 6.09325 | DR: 705.53118 --
# Pred-> Constructive: 2730, Active: 1047, Passive: 1178, None: 43
# Eval Time: 23.159374713897705
# --epoch: 7100/20000 | ECR: 46.16484 | IS: 25.17406 | WIS: 69.68250 | PDIS: 23.19186 | PDWIS: 5.83447 | DR: 625.78620 --
# Pred-> Constructive: 3070, Active: 961, Passive: 291, None: 676
# Eval Time: 23.14891529083252
# --epoch: 7200/20000 | ECR: 44.92695 | IS: 0.29343 | WIS: 14.29000 | PDIS: 0.29343 | PDWIS: 0.13097 | DR: 553.90920 --
# Pred-> Constructive: 0, Active: 399, Passive: 3781, None: 818
# Eval Time: 23.179792165756226
# --epoch: 7300/20000 | ECR: 45.72230 | IS: 27.09620 | WIS: 59.81122 | PDIS: 24.84626 | PDWIS: 5.52697 | DR: 647.66523 --
# Pred-> Constructive: 3423, Active: 759, Passive: 153, None: 663
# Eval Time: 23.260220050811768
# --epoch: 7400/20000 | ECR: 47.04140 | IS: 27.11253 | WIS: 59.84725 | PDIS: 24.86259 | PDWIS: 5.80683 | DR: 662.40824 --
# Pred-> Constructive: 3284, Active: 547, Passive: 115, None: 1052
# Eval Time: 23.28324604034424
# --epoch: 7500/20000 | ECR: 47.33526 | IS: 13.41509 | WIS: 68.32052 | PDIS: 12.75562 | PDWIS: 2.38086 | DR: 784.86680 --
# Pred-> Constructive: 440, Active: 3209, Passive: 89, None: 1260
# Eval Time: 23.134631872177124
# --epoch: 7600/20000 | ECR: 45.22017 | IS: 25.89296 | WIS: 71.41874 | PDIS: 23.80650 | PDWIS: 5.82575 | DR: 622.69075 --
# Pred-> Constructive: 3521, Active: 34, Passive: 184, None: 1259
# Eval Time: 23.180150985717773
# --epoch: 7700/20000 | ECR: 46.06140 | IS: 25.89296 | WIS: 71.41874 | PDIS: 23.80650 | PDWIS: 5.89066 | DR: 638.40640 --
# Pred-> Constructive: 3207, Active: 325, Passive: 644, None: 822
# Eval Time: 23.24097204208374
# --epoch: 7800/20000 | ECR: 46.50555 | IS: 30.11683 | WIS: 67.00081 | PDIS: 26.78469 | PDWIS: 5.59874 | DR: 801.92532 --
# Pred-> Constructive: 1007, Active: 2570, Passive: 1316, None: 105
# Eval Time: 23.101923942565918
# --epoch: 7900/20000 | ECR: 46.42586 | IS: 20.67336 | WIS: 74.75028 | PDIS: 18.97644 | PDWIS: 6.21954 | DR: 642.72002 --
# Pred-> Constructive: 1167, Active: 2842, Passive: 231, None: 758
# Eval Time: 23.274250030517578
# --epoch: 8000/20000 | ECR: 47.54500 | IS: 31.98224 | WIS: 76.09333 | PDIS: 29.46989 | PDWIS: 6.58909 | DR: 726.17092 --
# Pred-> Constructive: 2707, Active: 1337, Passive: 899, None: 55
# Eval Time: 23.235345363616943
# --epoch: 8100/20000 | ECR: 47.55012 | IS: 22.00004 | WIS: 76.35829 | PDIS: 20.22640 | PDWIS: 5.52371 | DR: 666.92026 --
# Pred-> Constructive: 3470, Active: 121, Passive: 284, None: 1123
# Eval Time: 23.29237723350525
# --epoch: 8200/20000 | ECR: 48.38805 | IS: 31.27642 | WIS: 63.79736 | PDIS: 28.69280 | PDWIS: 4.85658 | DR: 766.75553 --
# Pred-> Constructive: 3183, Active: 1166, Passive: 597, None: 52
# Eval Time: 23.057810306549072
# --epoch: 8300/20000 | ECR: 47.56459 | IS: 28.91900 | WIS: 70.08922 | PDIS: 26.46690 | PDWIS: 5.22206 | DR: 790.08927 --
# Pred-> Constructive: 2894, Active: 1290, Passive: 798, None: 16
# Eval Time: 23.04814910888672
# --epoch: 8400/20000 | ECR: 47.30225 | IS: 25.98903 | WIS: 62.11856 | PDIS: 23.68627 | PDWIS: 7.14668 | DR: 578.19251 --
# Pred-> Constructive: 2209, Active: 1185, Passive: 1604, None: 0
# Eval Time: 23.12690567970276
# --epoch: 8500/20000 | ECR: 52.95255 | IS: 28.16021 | WIS: 77.67234 | PDIS: 25.88605 | PDWIS: 6.49305 | DR: 745.44879 --
# Pred-> Constructive: 3402, Active: 572, Passive: 1018, None: 6
# Eval Time: 23.085116147994995
# --epoch: 8600/20000 | ECR: 54.39976 | IS: 28.98817 | WIS: 62.91805 | PDIS: 26.66670 | PDWIS: 5.79900 | DR: 754.99741 --
# Pred-> Constructive: 3150, Active: 1239, Passive: 488, None: 121
# Eval Time: 23.099889993667603
# --epoch: 8700/20000 | ECR: 54.02663 | IS: 26.57064 | WIS: 62.36096 | PDIS: 24.44582 | PDWIS: 5.66001 | DR: 758.68896 --
# Pred-> Constructive: 3212, Active: 944, Passive: 615, None: 227
# Eval Time: 23.191272020339966
# --epoch: 8800/20000 | ECR: 53.78837 | IS: 26.80307 | WIS: 72.89688 | PDIS: 24.69703 | PDWIS: 5.51014 | DR: 895.11872 --
# Pred-> Constructive: 3116, Active: 1165, Passive: 254, None: 463
# Eval Time: 23.21349811553955
# --epoch: 8900/20000 | ECR: 53.83077 | IS: 27.80583 | WIS: 77.51809 | PDIS: 25.50766 | PDWIS: 8.05625 | DR: 659.10642 --
# Pred-> Constructive: 2726, Active: 718, Passive: 1216, None: 338
# Eval Time: 23.05664086341858
# --epoch: 9000/20000 | ECR: 53.50485 | IS: 27.63835 | WIS: 74.90715 | PDIS: 25.35507 | PDWIS: 7.02960 | DR: 702.38048 --
# Pred-> Constructive: 2456, Active: 1396, Passive: 409, None: 737
# Eval Time: 23.13799285888672
# --epoch: 9100/20000 | ECR: 51.35366 | IS: 25.66743 | WIS: 75.90157 | PDIS: 23.45308 | PDWIS: 5.34997 | DR: 774.38132 --
# Pred-> Constructive: 2626, Active: 1677, Passive: 601, None: 94
# Eval Time: 23.1203510761261
# --epoch: 9200/20000 | ECR: 49.27109 | IS: 1.02669 | WIS: 100.00000 | PDIS: 1.02669 | PDWIS: 0.43821 | DR: 619.87790 --
# Pred-> Constructive: 26, Active: 477, Passive: 4485, None: 10
# Eval Time: 23.09797501564026
# --epoch: 9300/20000 | ECR: 45.54514 | IS: 26.46283 | WIS: 74.84514 | PDIS: 24.46139 | PDWIS: 5.96475 | DR: 622.37752 --
# Pred-> Constructive: 2836, Active: 610, Passive: 247, None: 1305
# Eval Time: 23.048094987869263
# --epoch: 9400/20000 | ECR: 43.00072 | IS: 22.06284 | WIS: 76.91886 | PDIS: 20.26884 | PDWIS: 5.20448 | DR: 607.59610 --
# Pred-> Constructive: 1976, Active: 1578, Passive: 621, None: 823
# Eval Time: 23.143372058868408
# --epoch: 9500/20000 | ECR: 43.92583 | IS: 26.40022 | WIS: 76.33045 | PDIS: 24.42972 | PDWIS: 6.29040 | DR: 560.59156 --
# Pred-> Constructive: 3340, Active: 346, Passive: 1215, None: 97
# Eval Time: 23.278157234191895
# --epoch: 9600/20000 | ECR: 41.94244 | IS: 15.72086 | WIS: 84.19034 | PDIS: 14.34324 | PDWIS: 21.90364 | DR: 653.58067 --
# Pred-> Constructive: 1191, Active: 1155, Passive: 2441, None: 211
# Eval Time: 23.087007999420166
# --epoch: 9700/20000 | ECR: 44.25856 | IS: 21.50710 | WIS: 75.65840 | PDIS: 19.73725 | PDWIS: 6.78301 | DR: 603.92254 --
# Pred-> Constructive: 2244, Active: 380, Passive: 2090, None: 284
# Eval Time: 23.116372108459473
# --epoch: 9800/20000 | ECR: 44.90066 | IS: 21.15741 | WIS: 75.79703 | PDIS: 19.41698 | PDWIS: 5.96316 | DR: 644.29051 --
# Pred-> Constructive: 1787, Active: 2639, Passive: 235, None: 337
# Eval Time: 23.114173889160156
# --epoch: 9900/20000 | ECR: 47.92924 | IS: 29.58168 | WIS: 75.94743 | PDIS: 27.19757 | PDWIS: 6.82039 | DR: 642.51010 --
# Pred-> Constructive: 2464, Active: 1842, Passive: 454, None: 238
# Eval Time: 23.18880820274353
# --epoch: 10000/20000 | ECR: 49.98430 | IS: 26.09060 | WIS: 74.33197 | PDIS: 24.13843 | PDWIS: 6.23717 | DR: 643.10728 --
# Pred-> Constructive: 3258, Active: 807, Passive: 664, None: 269
# Eval Time: 23.122126817703247
# --epoch: 10100/20000 | ECR: 49.83307 | IS: 30.29854 | WIS: 66.13059 | PDIS: 27.85173 | PDWIS: 6.45934 | DR: 672.80608 --
# Pred-> Constructive: 2817, Active: 1335, Passive: 714, None: 132
# Eval Time: 23.153156757354736
# --epoch: 10200/20000 | ECR: 50.45200 | IS: 29.09530 | WIS: 78.04150 | PDIS: 26.81197 | PDWIS: 6.50785 | DR: 660.75616 --
# Pred-> Constructive: 4151, Active: 277, Passive: 345, None: 225
# Eval Time: 23.124842882156372
# --epoch: 10300/20000 | ECR: 51.28428 | IS: 28.33959 | WIS: 76.27705 | PDIS: 25.99558 | PDWIS: 6.90989 | DR: 700.56437 --
# Pred-> Constructive: 3045, Active: 1106, Passive: 454, None: 393
# Eval Time: 23.24919104576111
# --epoch: 10400/20000 | ECR: 53.56583 | IS: 28.33041 | WIS: 80.41914 | PDIS: 26.06528 | PDWIS: 7.02902 | DR: 757.78343 --
# Pred-> Constructive: 3345, Active: 731, Passive: 680, None: 242
# Eval Time: 23.175561904907227
# --epoch: 10500/20000 | ECR: 55.31646 | IS: 22.65441 | WIS: 80.78863 | PDIS: 20.86644 | PDWIS: 28.06289 | DR: 465.70973 --
# Pred-> Constructive: 1898, Active: 719, Passive: 2216, None: 165
# Eval Time: 23.19881296157837
# --epoch: 10600/20000 | ECR: 54.63594 | IS: 11.51407 | WIS: 77.34276 | PDIS: 10.92051 | PDWIS: 14.38553 | DR: 426.65028 --
# Pred-> Constructive: 818, Active: 1179, Passive: 2836, None: 165
# Eval Time: 23.139957904815674
# --epoch: 10700/20000 | ECR: 52.96660 | IS: 25.74943 | WIS: 78.52820 | PDIS: 23.74008 | PDWIS: 6.91277 | DR: 1011.82826 --
# Pred-> Constructive: 2161, Active: 1459, Passive: 868, None: 510
# Eval Time: 23.129362106323242
# --epoch: 10800/20000 | ECR: 55.67692 | IS: 28.72254 | WIS: 77.30779 | PDIS: 26.37853 | PDWIS: 7.06380 | DR: 731.31807 --
# Pred-> Constructive: 3057, Active: 1113, Passive: 405, None: 423
# Eval Time: 23.159340620040894
# --epoch: 10900/20000 | ECR: 57.76236 | IS: 26.17365 | WIS: 81.74150 | PDIS: 24.12472 | PDWIS: 10.12577 | DR: 669.47617 --
# Pred-> Constructive: 1971, Active: 1181, Passive: 1510, None: 336
# Eval Time: 23.151296138763428
# --epoch: 11000/20000 | ECR: 56.03030 | IS: 30.18776 | WIS: 76.99609 | PDIS: 27.74483 | PDWIS: 7.04484 | DR: 722.44208 --
# Pred-> Constructive: 3634, Active: 705, Passive: 636, None: 23
# Eval Time: 23.21137499809265
# --epoch: 11100/20000 | ECR: 56.86739 | IS: 19.11011 | WIS: 69.42002 | PDIS: 17.53603 | PDWIS: 27.67192 | DR: 441.94537 --
# Pred-> Constructive: 1191, Active: 566, Passive: 3222, None: 19
# Eval Time: 23.215003967285156
# --epoch: 11200/20000 | ECR: 55.66758 | IS: 30.41235 | WIS: 81.29436 | PDIS: 27.86915 | PDWIS: 9.68962 | DR: 691.82125 --
# Pred-> Constructive: 2352, Active: 743, Passive: 616, None: 1287
# Eval Time: 23.137584924697876
# --epoch: 11300/20000 | ECR: 55.61224 | IS: 27.11267 | WIS: 78.39033 | PDIS: 25.03801 | PDWIS: 6.13289 | DR: 763.06274 --
# Pred-> Constructive: 2848, Active: 1157, Passive: 155, None: 838
# Eval Time: 23.144656896591187
# --epoch: 11400/20000 | ECR: 59.02987 | IS: 31.23780 | WIS: 79.93594 | PDIS: 28.80448 | PDWIS: 8.34910 | DR: 775.89020 --
# Pred-> Constructive: 2591, Active: 948, Passive: 750, None: 709
# Eval Time: 23.09958004951477
# --epoch: 11500/20000 | ECR: 59.71550 | IS: 25.03896 | WIS: 77.88565 | PDIS: 23.18705 | PDWIS: 6.32259 | DR: 788.29469 --
# Pred-> Constructive: 3028, Active: 641, Passive: 1258, None: 71
# Eval Time: 23.25557518005371
# --epoch: 11600/20000 | ECR: 59.07498 | IS: 27.08002 | WIS: 74.42947 | PDIS: 24.96564 | PDWIS: 9.00933 | DR: 682.43317 --
# Pred-> Constructive: 2478, Active: 857, Passive: 1562, None: 101
# Eval Time: 23.12685227394104
# --epoch: 11700/20000 | ECR: 54.07612 | IS: 27.18717 | WIS: 73.17528 | PDIS: 25.06094 | PDWIS: 10.07452 | DR: 639.37466 --
# Pred-> Constructive: 1909, Active: 958, Passive: 2043, None: 88
# Eval Time: 23.193170070648193
# --epoch: 11800/20000 | ECR: 52.26047 | IS: 30.61383 | WIS: 72.61581 | PDIS: 28.47739 | PDWIS: 7.85819 | DR: 684.92038 --
# Pred-> Constructive: 3071, Active: 437, Passive: 1461, None: 29
# Eval Time: 23.16294813156128
# --epoch: 11900/20000 | ECR: 51.18113 | IS: 28.51315 | WIS: 77.27807 | PDIS: 26.34628 | PDWIS: 8.79722 | DR: 656.78468 --
# Pred-> Constructive: 2187, Active: 867, Passive: 1446, None: 498
# Eval Time: 23.16779112815857
# --epoch: 12000/20000 | ECR: 54.31620 | IS: 33.59469 | WIS: 81.42142 | PDIS: 30.88688 | PDWIS: 7.87117 | DR: 723.72724 --
# Pred-> Constructive: 2990, Active: 824, Passive: 293, None: 891
# Eval Time: 23.11808204650879
# --epoch: 12100/20000 | ECR: 56.15858 | IS: 36.64736 | WIS: 80.89412 | PDIS: 33.12160 | PDWIS: 13.47617 | DR: 679.67159 --
# Pred-> Constructive: 1944, Active: 890, Passive: 1486, None: 678
# Eval Time: 23.151929140090942
# --epoch: 12200/20000 | ECR: 55.65930 | IS: 26.67383 | WIS: 78.57938 | PDIS: 24.40802 | PDWIS: 8.39884 | DR: 681.70280 --
# Pred-> Constructive: 2377, Active: 783, Passive: 1659, None: 179
# Eval Time: 23.101351976394653
# --epoch: 12300/20000 | ECR: 54.83087 | IS: 22.26604 | WIS: 70.67086 | PDIS: 20.63041 | PDWIS: 7.07644 | DR: 627.70534 --
# Pred-> Constructive: 2877, Active: 382, Passive: 1708, None: 31
# Eval Time: 23.11602783203125
# --epoch: 12400/20000 | ECR: 55.06570 | IS: 23.52244 | WIS: 75.27181 | PDIS: 21.56946 | PDWIS: 17.28036 | DR: 495.13968 --
# Pred-> Constructive: 1613, Active: 1477, Passive: 1526, None: 382
# Eval Time: 23.096186876296997
# --epoch: 12500/20000 | ECR: 55.12864 | IS: 28.32983 | WIS: 76.78123 | PDIS: 26.16296 | PDWIS: 8.69437 | DR: 665.58378 --
# Pred-> Constructive: 2767, Active: 723, Passive: 1472, None: 36
# Eval Time: 23.098646879196167
# --epoch: 12600/20000 | ECR: 56.39591 | IS: 33.96233 | WIS: 77.26553 | PDIS: 31.40870 | PDWIS: 6.56099 | DR: 796.15727 --
# Pred-> Constructive: 2928, Active: 1065, Passive: 630, None: 375
# Eval Time: 23.098714113235474
# --epoch: 12700/20000 | ECR: 59.24325 | IS: 27.44385 | WIS: 75.69644 | PDIS: 25.21614 | PDWIS: 7.13713 | DR: 747.83770 --
# Pred-> Constructive: 3319, Active: 686, Passive: 724, None: 269
# Eval Time: 23.048754930496216
# --epoch: 12800/20000 | ECR: 55.49425 | IS: 18.83257 | WIS: 71.75714 | PDIS: 17.22388 | PDWIS: 16.56373 | DR: 470.11516 --
# Pred-> Constructive: 1243, Active: 1368, Passive: 2078, None: 309
# Eval Time: 23.181772708892822
# --epoch: 12900/20000 | ECR: 57.16408 | IS: 30.35884 | WIS: 81.15130 | PDIS: 27.81831 | PDWIS: 7.99155 | DR: 745.87510 --
# Pred-> Constructive: 3378, Active: 875, Passive: 577, None: 168
# Eval Time: 23.07946014404297
# --epoch: 13000/20000 | ECR: 60.43845 | IS: 28.54382 | WIS: 76.03879 | PDIS: 26.26112 | PDWIS: 7.54131 | DR: 776.31085 --
# Pred-> Constructive: 3044, Active: 655, Passive: 494, None: 805
# Eval Time: 23.053658962249756
# --epoch: 13100/20000 | ECR: 61.03954 | IS: 27.48644 | WIS: 77.74024 | PDIS: 25.39116 | PDWIS: 7.28046 | DR: 779.93495 --
# Pred-> Constructive: 3653, Active: 440, Passive: 762, None: 143
# Eval Time: 23.069203853607178
# --epoch: 13200/20000 | ECR: 60.65604 | IS: 20.68672 | WIS: 69.93100 | PDIS: 19.00814 | PDWIS: 8.36883 | DR: 661.21358 --
# Pred-> Constructive: 2293, Active: 1245, Passive: 1360, None: 100
# Eval Time: 23.085701942443848
# --epoch: 13300/20000 | ECR: 58.67162 | IS: 25.63485 | WIS: 75.23418 | PDIS: 23.57623 | PDWIS: 9.72225 | DR: 655.78858 --
# Pred-> Constructive: 2911, Active: 864, Passive: 1120, None: 103
# Eval Time: 23.05414915084839
# --epoch: 13400/20000 | ECR: 58.81694 | IS: 30.17289 | WIS: 77.85005 | PDIS: 27.38349 | PDWIS: 12.92129 | DR: 497.31767 --
# Pred-> Constructive: 1280, Active: 1532, Passive: 2184, None: 2
# Eval Time: 23.15376877784729
# --epoch: 13500/20000 | ECR: 57.75005 | IS: 31.14866 | WIS: 81.85847 | PDIS: 28.70503 | PDWIS: 7.99566 | DR: 712.95796 --
# Pred-> Constructive: 3827, Active: 473, Passive: 681, None: 17
# Eval Time: 23.067443370819092
# --epoch: 13600/20000 | ECR: 60.93063 | IS: 29.39726 | WIS: 78.04547 | PDIS: 27.17335 | PDWIS: 9.92222 | DR: 737.48370 --
# Pred-> Constructive: 2785, Active: 886, Passive: 1302, None: 25
# Eval Time: 23.11764693260193
# --epoch: 13700/20000 | ECR: 62.11212 | IS: 19.24304 | WIS: 69.25716 | PDIS: 17.61831 | PDWIS: 7.51025 | DR: 682.51576 --
# Pred-> Constructive: 2035, Active: 636, Passive: 2148, None: 179
# Eval Time: 23.16050100326538
# --epoch: 13800/20000 | ECR: 59.93578 | IS: 30.44953 | WIS: 79.61837 | PDIS: 27.36913 | PDWIS: 9.23430 | DR: 682.23127 --
# Pred-> Constructive: 1745, Active: 1631, Passive: 928, None: 694
# Eval Time: 23.10486602783203
# --epoch: 13900/20000 | ECR: 60.06870 | IS: 14.12330 | WIS: 65.70075 | PDIS: 12.85081 | PDWIS: 12.71829 | DR: 533.92315 --
# Pred-> Constructive: 1041, Active: 738, Passive: 2993, None: 226
# Eval Time: 23.074529886245728
# --epoch: 14000/20000 | ECR: 53.76375 | IS: 22.14536 | WIS: 77.20655 | PDIS: 20.24738 | PDWIS: 8.19832 | DR: 595.03308 --
# Pred-> Constructive: 1888, Active: 1536, Passive: 759, None: 815
# Eval Time: 23.067337036132812
# --epoch: 14100/20000 | ECR: 55.84194 | IS: 22.22539 | WIS: 72.30908 | PDIS: 20.32260 | PDWIS: 9.29741 | DR: 618.97309 --
# Pred-> Constructive: 1530, Active: 1533, Passive: 1460, None: 475
# Eval Time: 23.099610805511475
# --epoch: 14200/20000 | ECR: 58.75734 | IS: 20.96634 | WIS: 72.77049 | PDIS: 19.28112 | PDWIS: 10.73293 | DR: 672.12552 --
# Pred-> Constructive: 2458, Active: 1119, Passive: 795, None: 626
# Eval Time: 23.03166913986206
# --epoch: 14300/20000 | ECR: 62.01362 | IS: 29.95852 | WIS: 71.49671 | PDIS: 27.53131 | PDWIS: 9.82437 | DR: 703.17930 --
# Pred-> Constructive: 3168, Active: 474, Passive: 1280, None: 76
# Eval Time: 23.130285024642944
# --epoch: 14400/20000 | ECR: 61.89540 | IS: 25.15051 | WIS: 72.71716 | PDIS: 23.12894 | PDWIS: 6.39661 | DR: 772.24128 --
# Pred-> Constructive: 3636, Active: 467, Passive: 865, None: 30
# Eval Time: 23.033071994781494
# --epoch: 14500/20000 | ECR: 60.69927 | IS: 22.25948 | WIS: 71.23033 | PDIS: 20.30079 | PDWIS: 7.81850 | DR: 710.94041 --
# Pred-> Constructive: 1995, Active: 1008, Passive: 1991, None: 4
# Eval Time: 23.04134774208069
# --epoch: 14600/20000 | ECR: 60.40997 | IS: 26.27345 | WIS: 69.28012 | PDIS: 24.19574 | PDWIS: 8.59439 | DR: 688.72083 --
# Pred-> Constructive: 2725, Active: 1000, Passive: 1266, None: 7
# Eval Time: 23.105697870254517
# --epoch: 14700/20000 | ECR: 57.29178 | IS: 23.77602 | WIS: 68.23674 | PDIS: 21.81034 | PDWIS: 7.44469 | DR: 673.09939 --
# Pred-> Constructive: 2761, Active: 948, Passive: 869, None: 420
# Eval Time: 23.1217679977417
# --epoch: 14800/20000 | ECR: 57.65755 | IS: 27.00228 | WIS: 73.43866 | PDIS: 24.72289 | PDWIS: 9.68846 | DR: 657.52237 --
# Pred-> Constructive: 2952, Active: 633, Passive: 1273, None: 140
# Eval Time: 23.130565881729126
# --epoch: 14900/20000 | ECR: 57.66500 | IS: 20.72753 | WIS: 70.06896 | PDIS: 19.04691 | PDWIS: 8.90870 | DR: 625.93474 --
# Pred-> Constructive: 2822, Active: 470, Passive: 1675, None: 31
# Eval Time: 23.123667001724243
# --epoch: 15000/20000 | ECR: 54.51732 | IS: 8.37141 | WIS: 56.72174 | PDIS: 8.02329 | PDWIS: 5.83410 | DR: 430.08026 --
# Pred-> Constructive: 1371, Active: 933, Passive: 2080, None: 614
# Eval Time: 23.081602811813354
# --epoch: 15100/20000 | ECR: 55.08685 | IS: 25.56872 | WIS: 69.78335 | PDIS: 23.51819 | PDWIS: 8.68485 | DR: 631.22796 --
# Pred-> Constructive: 2256, Active: 1379, Passive: 942, None: 421
# Eval Time: 23.049641132354736
# --epoch: 15200/20000 | ECR: 53.88623 | IS: 26.79243 | WIS: 76.05342 | PDIS: 24.54780 | PDWIS: 8.29538 | DR: 656.29770 --
# Pred-> Constructive: 3232, Active: 666, Passive: 1065, None: 35
# Eval Time: 23.028262853622437
# --epoch: 15300/20000 | ECR: 56.52197 | IS: 25.43173 | WIS: 71.66873 | PDIS: 23.24413 | PDWIS: 12.55438 | DR: 616.48811 --
# Pred-> Constructive: 2462, Active: 857, Passive: 1452, None: 227
# Eval Time: 23.0289568901062
# --epoch: 15400/20000 | ECR: 55.08141 | IS: 23.13951 | WIS: 68.94954 | PDIS: 21.18082 | PDWIS: 12.28637 | DR: 579.62042 --
# Pred-> Constructive: 2902, Active: 920, Passive: 946, None: 230
# Eval Time: 23.085585117340088
# --epoch: 15500/20000 | ECR: 54.50261 | IS: 509.37089 | WIS: 62.52868 | PDIS: 343.35049 | PDWIS: 9.03897 | DR: 1191.16359 --
# Pred-> Constructive: 1408, Active: 1765, Passive: 1011, None: 814
# Eval Time: 23.090989112854004
# --epoch: 15600/20000 | ECR: 50.98170 | IS: 22.95046 | WIS: 71.38920 | PDIS: 21.15869 | PDWIS: 8.72598 | DR: 572.88458 --
# Pred-> Constructive: 1998, Active: 1676, Passive: 1272, None: 52
# Eval Time: 23.029202938079834
# --epoch: 15700/20000 | ECR: 54.30980 | IS: 23.08245 | WIS: 70.39470 | PDIS: 21.12947 | PDWIS: 8.43606 | DR: 643.96321 --
# Pred-> Constructive: 1697, Active: 1809, Passive: 1454, None: 38
# Eval Time: 23.106637716293335
# --epoch: 15800/20000 | ECR: 55.23373 | IS: 21.80466 | WIS: 61.89505 | PDIS: 20.08919 | PDWIS: 5.35422 | DR: 714.47442 --
# Pred-> Constructive: 2219, Active: 2149, Passive: 612, None: 18
# Eval Time: 23.024715900421143
# --epoch: 15900/20000 | ECR: 55.29870 | IS: 15.09005 | WIS: 70.40820 | PDIS: 14.18457 | PDWIS: 4.02118 | DR: 732.40693 --
# Pred-> Constructive: 2832, Active: 986, Passive: 1170, None: 10
# Eval Time: 23.091798067092896
# --epoch: 16000/20000 | ECR: 57.39984 | IS: 24.60619 | WIS: 72.21524 | PDIS: 22.59617 | PDWIS: 13.01149 | DR: 598.09406 --
# Pred-> Constructive: 2589, Active: 610, Passive: 1419, None: 380
# Eval Time: 23.106324911117554
# --epoch: 16100/20000 | ECR: 55.61128 | IS: 20.61344 | WIS: 69.68328 | PDIS: 18.93853 | PDWIS: 7.32080 | DR: 649.62011 --
# Pred-> Constructive: 3006, Active: 563, Passive: 1122, None: 307
# Eval Time: 23.02166199684143
# --epoch: 16200/20000 | ECR: 54.39762 | IS: 21.31424 | WIS: 70.22433 | PDIS: 19.58228 | PDWIS: 6.39515 | DR: 613.52071 --
# Pred-> Constructive: 2106, Active: 1291, Passive: 1586, None: 15
# Eval Time: 23.13771915435791
# --epoch: 16300/20000 | ECR: 54.03084 | IS: 22.74539 | WIS: 71.60891 | PDIS: 20.79240 | PDWIS: 7.12879 | DR: 605.40349 --
# Pred-> Constructive: 2388, Active: 936, Passive: 1660, None: 14
# Eval Time: 23.007933139801025
# --epoch: 16400/20000 | ECR: 55.34321 | IS: 22.74539 | WIS: 71.60891 | PDIS: 20.79240 | PDWIS: 7.05501 | DR: 690.80115 --
# Pred-> Constructive: 2803, Active: 1066, Passive: 1118, None: 11
# Eval Time: 23.095574140548706
# --epoch: 16500/20000 | ECR: 57.87969 | IS: 25.62829 | WIS: 75.49930 | PDIS: 23.44069 | PDWIS: 6.41702 | DR: 803.54429 --
# Pred-> Constructive: 2971, Active: 1352, Passive: 663, None: 12
# Eval Time: 23.051517963409424
# --epoch: 16600/20000 | ECR: 58.40208 | IS: 20.40210 | WIS: 73.42871 | PDIS: 18.68708 | PDWIS: 7.70065 | DR: 657.13472 --
# Pred-> Constructive: 3174, Active: 681, Passive: 1140, None: 3
# Eval Time: 23.03952980041504
# --epoch: 16700/20000 | ECR: 59.10001 | IS: 511.69547 | WIS: 62.73004 | PDIS: 344.91454 | PDWIS: 11.25705 | DR: 1140.27881 --
# Pred-> Constructive: 1517, Active: 1390, Passive: 2040, None: 51
# Eval Time: 23.08455991744995
# --epoch: 16800/20000 | ECR: 58.08063 | IS: 31.92487 | WIS: 78.72106 | PDIS: 28.81429 | PDWIS: 9.49293 | DR: 760.59917 --
# Pred-> Constructive: 2855, Active: 1297, Passive: 681, None: 165
# Eval Time: 23.024433135986328
# --epoch: 16900/20000 | ECR: 59.58584 | IS: 36.34322 | WIS: 81.60990 | PDIS: 32.86483 | PDWIS: 10.50809 | DR: 712.59776 --
# Pred-> Constructive: 2638, Active: 881, Passive: 1325, None: 154
# Eval Time: 23.055933237075806
# --epoch: 17000/20000 | ECR: 57.52590 | IS: 25.53497 | WIS: 75.22437 | PDIS: 23.34737 | PDWIS: 7.87062 | DR: 758.59013 --
# Pred-> Constructive: 2612, Active: 1075, Passive: 1144, None: 167
# Eval Time: 23.007301807403564
# --epoch: 17100/20000 | ECR: 58.84882 | IS: 25.01758 | WIS: 73.97987 | PDIS: 23.01090 | PDWIS: 8.33754 | DR: 695.10169 --
# Pred-> Constructive: 3188, Active: 523, Passive: 1178, None: 109
# Eval Time: 23.07630491256714
# --epoch: 17200/20000 | ECR: 62.37459 | IS: 20.02001 | WIS: 74.10734 | PDIS: 18.34510 | PDWIS: 9.06906 | DR: 680.96672 --
# Pred-> Constructive: 2197, Active: 958, Passive: 1833, None: 10
# Eval Time: 23.119528770446777
# --epoch: 17300/20000 | ECR: 61.96690 | IS: 507.54930 | WIS: 62.70019 | PDIS: 341.60246 | PDWIS: 10.41124 | DR: 1169.96334 --
# Pred-> Constructive: 1704, Active: 1856, Passive: 1377, None: 61
# Eval Time: 23.061758995056152
# --epoch: 17400/20000 | ECR: 58.63885 | IS: 14.05483 | WIS: 75.52772 | PDIS: 13.35539 | PDWIS: 4.81878 | DR: 625.31326 --
# Pred-> Constructive: 1049, Active: 1219, Passive: 2631, None: 99
# Eval Time: 23.03875994682312
# --epoch: 17500/20000 | ECR: 55.44499 | IS: 20.71829 | WIS: 76.32953 | PDIS: 19.07982 | PDWIS: 8.93906 | DR: 601.55367 --
# Pred-> Constructive: 1915, Active: 1410, Passive: 1672, None: 1
# Eval Time: 22.98027777671814
# --epoch: 17600/20000 | ECR: 53.72323 | IS: 20.29517 | WIS: 73.72492 | PDIS: 18.63589 | PDWIS: 8.42495 | DR: 597.71011 --
# Pred-> Constructive: 2688, Active: 667, Passive: 1058, None: 585
# Eval Time: 23.108866930007935
# --epoch: 17700/20000 | ECR: 53.83852 | IS: 17.84003 | WIS: 68.98737 | PDIS: 16.41538 | PDWIS: 10.60669 | DR: 565.54705 --
# Pred-> Constructive: 1821, Active: 1299, Passive: 1842, None: 36
# Eval Time: 23.08208179473877
# --epoch: 17800/20000 | ECR: 54.45138 | IS: 23.37661 | WIS: 75.11363 | PDIS: 21.59499 | PDWIS: 7.92146 | DR: 638.44554 --
# Pred-> Constructive: 2983, Active: 1170, Passive: 786, None: 59
# Eval Time: 23.00374126434326
# --epoch: 17900/20000 | ECR: 53.61014 | IS: 23.11539 | WIS: 76.80817 | PDIS: 21.28152 | PDWIS: 12.32343 | DR: 564.76992 --
# Pred-> Constructive: 2410, Active: 482, Passive: 1095, None: 1011
# Eval Time: 23.047348022460938
# --epoch: 18000/20000 | ECR: 54.45669 | IS: 23.11994 | WIS: 75.53482 | PDIS: 21.33831 | PDWIS: 12.17636 | DR: 594.05089 --
# Pred-> Constructive: 2476, Active: 335, Passive: 840, None: 1347
# Eval Time: 23.026346921920776
# --epoch: 18100/20000 | ECR: 55.16333 | IS: 25.21511 | WIS: 73.44903 | PDIS: 23.22572 | PDWIS: 7.74402 | DR: 679.65008 --
# Pred-> Constructive: 3324, Active: 708, Passive: 632, None: 334
# Eval Time: 23.04461121559143
# --epoch: 18200/20000 | ECR: 59.58705 | IS: 28.33136 | WIS: 80.56859 | PDIS: 25.59451 | PDWIS: 13.18417 | DR: 682.94124 --
# Pred-> Constructive: 2290, Active: 672, Passive: 1476, None: 560
# Eval Time: 23.02963900566101
# --epoch: 18300/20000 | ECR: 60.04282 | IS: 23.31704 | WIS: 71.38953 | PDIS: 21.47394 | PDWIS: 7.16381 | DR: 666.01894 --
# Pred-> Constructive: 2999, Active: 1056, Passive: 894, None: 49
# Eval Time: 23.050148963928223
# --epoch: 18400/20000 | ECR: 59.24546 | IS: 23.36288 | WIS: 74.45544 | PDIS: 21.55106 | PDWIS: 9.14943 | DR: 696.20280 --
# Pred-> Constructive: 2242, Active: 906, Passive: 1417, None: 433
# Eval Time: 23.036724090576172
# --epoch: 18500/20000 | ECR: 58.63459 | IS: 25.60540 | WIS: 76.88526 | PDIS: 23.50122 | PDWIS: 7.47490 | DR: 776.77455 --
# Pred-> Constructive: 2465, Active: 1053, Passive: 1395, None: 85
# Eval Time: 22.994126081466675
# --epoch: 18600/20000 | ECR: 55.65735 | IS: 505.36044 | WIS: 62.78815 | PDIS: 339.69353 | PDWIS: 8.99540 | DR: 1111.23326 --
# Pred-> Constructive: 1440, Active: 1895, Passive: 1663, None: 0
# Eval Time: 23.001973867416382
# --epoch: 18700/20000 | ECR: 55.78217 | IS: 22.14368 | WIS: 77.20069 | PDIS: 20.48827 | PDWIS: 11.28723 | DR: 610.98335 --
# Pred-> Constructive: 2890, Active: 435, Passive: 1641, None: 32
# Eval Time: 22.996349096298218
# --epoch: 18800/20000 | ECR: 57.34670 | IS: 26.42167 | WIS: 74.45846 | PDIS: 24.23407 | PDWIS: 8.56844 | DR: 672.06365 --
# Pred-> Constructive: 2730, Active: 1054, Passive: 996, None: 218
# Eval Time: 23.12529683113098
# --epoch: 18900/20000 | ECR: 57.32322 | IS: 21.82712 | WIS: 70.71807 | PDIS: 20.11081 | PDWIS: 11.95791 | DR: 585.52827 --
# Pred-> Constructive: 2673, Active: 1058, Passive: 1187, None: 80
# Eval Time: 23.011062145233154
# --epoch: 19000/20000 | ECR: 57.22240 | IS: 18.71264 | WIS: 66.27677 | PDIS: 17.53685 | PDWIS: 5.68421 | DR: 612.94571 --
# Pred-> Constructive: 2842, Active: 1119, Passive: 878, None: 159
# Eval Time: 23.071143865585327
# --epoch: 19100/20000 | ECR: 56.14174 | IS: 23.85860 | WIS: 74.51152 | PDIS: 21.87987 | PDWIS: 10.76265 | DR: 567.05417 --
# Pred-> Constructive: 2857, Active: 689, Passive: 1445, None: 7
# Eval Time: 23.041127920150757
# --epoch: 19200/20000 | ECR: 54.59755 | IS: 15.43659 | WIS: 66.82328 | PDIS: 14.59478 | PDWIS: 4.03325 | DR: 770.61192 --
# Pred-> Constructive: 1762, Active: 1929, Passive: 1090, None: 217
# Eval Time: 23.034877061843872
# --epoch: 19300/20000 | ECR: 54.41094 | IS: 23.57368 | WIS: 69.97568 | PDIS: 21.73975 | PDWIS: 8.88673 | DR: 642.32923 --
# Pred-> Constructive: 2893, Active: 657, Passive: 1297, None: 151
# Eval Time: 23.073830127716064
# --epoch: 19400/20000 | ECR: 55.10122 | IS: 27.50701 | WIS: 77.51705 | PDIS: 25.25355 | PDWIS: 6.78950 | DR: 694.57572 --
# Pred-> Constructive: 3427, Active: 744, Passive: 290, None: 537
# Eval Time: 23.028486013412476
# --epoch: 19500/20000 | ECR: 56.20119 | IS: 25.40559 | WIS: 75.99246 | PDIS: 23.51556 | PDWIS: 8.36126 | DR: 622.83638 --
# Pred-> Constructive: 2608, Active: 961, Passive: 1220, None: 209
# Eval Time: 23.203238010406494
# --epoch: 19600/20000 | ECR: 53.64435 | IS: 514.62584 | WIS: 62.98028 | PDIS: 347.78389 | PDWIS: 9.68571 | DR: 1255.56328 --
# Pred-> Constructive: 3190, Active: 873, Passive: 895, None: 40
# Eval Time: 23.127691984176636
# --epoch: 19700/20000 | ECR: 55.37136 | IS: 43.97344 | WIS: 79.91629 | PDIS: 38.47946 | PDWIS: 8.45117 | DR: 782.66684 --
# Pred-> Constructive: 2106, Active: 1554, Passive: 1305, None: 33
# Eval Time: 23.023164987564087
# --epoch: 19800/20000 | ECR: 56.23463 | IS: 27.31451 | WIS: 74.81007 | PDIS: 25.02977 | PDWIS: 9.62104 | DR: 675.19019 --
# Pred-> Constructive: 2378, Active: 969, Passive: 1534, None: 117
# Eval Time: 23.062756061553955
# --epoch: 19900/20000 | ECR: 58.47289 | IS: 22.33636 | WIS: 72.97482 | PDIS: 20.54826 | PDWIS: 7.63855 | DR: 650.16779 --
# Pred-> Constructive: 2125, Active: 1192, Passive: 1463, None: 218
# Eval Time: 23.015954971313477
# --epoch: 20000/20000 | ECR: 57.80578 | IS: 20.72297 | WIS: 75.63155 | PDIS: 19.12256 | PDWIS: 8.50578 | DR: 603.55698 --
# Pred-> Constructive: 2470, Active: 805, Passive: 1532, None: 191
# True-> Constructive: 2009, Active: 2074, Passive: 445, None: 470
# Pred-> Constructive: 2470, Active: 805, Passive: 1532, None: 191
# -> True Reward: 54.63407/30.52030, Pred Reward: 57.80578/18.66534
# TF INFO: [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18268853596839721465
# ]
# GPU INFO: []
# ===== STARTING  DQN_is_lstm_True_lookback_1_run_20000_rs_2 =====
# Eval Time: 23.532651901245117
# --epoch: 100/20000 | ECR: 4.81931 | IS: 11.06635 | WIS: 70.67951 | PDIS: 10.47618 | PDWIS: 7.26765 | DR: 61.29935 --
# Pred-> Constructive: 2529, Active: 0, Passive: 0, None: 2469
# Eval Time: 23.612401962280273
# --epoch: 200/20000 | ECR: 12.51390 | IS: 15.12631 | WIS: 66.96830 | PDIS: 14.14867 | PDWIS: 3.16687 | DR: 349.79240 --
# Pred-> Constructive: 0, Active: 4239, Passive: 759, None: 0
# Eval Time: 23.670477867126465
# --epoch: 300/20000 | ECR: 22.75375 | IS: 16.17968 | WIS: 49.73258 | PDIS: 15.28113 | PDWIS: 5.00928 | DR: 356.34562 --
# Pred-> Constructive: 2817, Active: 0, Passive: 2181, None: 0
# Eval Time: 23.645155906677246
# --epoch: 400/20000 | ECR: 29.91291 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 681.29996 --
# Pred-> Constructive: 0, Active: 0, Passive: 4998, None: 0
# Eval Time: 23.66345191001892
# --epoch: 500/20000 | ECR: 30.60277 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 634.90435 --
# Pred-> Constructive: 0, Active: 0, Passive: 4998, None: 0
# Eval Time: 23.603727102279663
# --epoch: 600/20000 | ECR: 35.95343 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 649.17353 --
# Pred-> Constructive: 0, Active: 0, Passive: 4998, None: 0
# Eval Time: 23.650996923446655
# --epoch: 700/20000 | ECR: 40.58756 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 693.82325 --
# Pred-> Constructive: 0, Active: 0, Passive: 4854, None: 144
# Eval Time: 23.63700008392334
# --epoch: 800/20000 | ECR: 40.88431 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12524 | DR: 718.98872 --
# Pred-> Constructive: 0, Active: 0, Passive: 4276, None: 722
# Eval Time: 23.69119882583618
# --epoch: 900/20000 | ECR: 36.76144 | IS: 13.03418 | WIS: 43.12624 | PDIS: 12.28779 | PDWIS: 3.42363 | DR: 469.91619 --
# Pred-> Constructive: 2668, Active: 16, Passive: 1721, None: 593
# Eval Time: 23.627142906188965
# --epoch: 1000/20000 | ECR: 38.91727 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12524 | DR: 659.47771 --
# Pred-> Constructive: 0, Active: 0, Passive: 4462, None: 536
# Eval Time: 23.672260284423828
# --epoch: 1100/20000 | ECR: 36.31056 | IS: 65.64879 | WIS: 67.16368 | PDIS: 54.90670 | PDWIS: 11.96388 | DR: 568.23855 --
# Pred-> Constructive: 3031, Active: 38, Passive: 658, None: 1271
# Eval Time: 23.614530086517334
# --epoch: 1200/20000 | ECR: 37.00538 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 614.11018 --
# Pred-> Constructive: 0, Active: 0, Passive: 4510, None: 488
# Eval Time: 23.58003306388855
# --epoch: 1300/20000 | ECR: 37.91485 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 631.05212 --
# Pred-> Constructive: 0, Active: 0, Passive: 4998, None: 0
# Eval Time: 23.61292314529419
# --epoch: 1400/20000 | ECR: 47.37188 | IS: 0.29343 | WIS: 7.14500 | PDIS: 0.29343 | PDWIS: 0.12219 | DR: 717.57253 --
# Pred-> Constructive: 0, Active: 3, Passive: 4841, None: 154
# Eval Time: 23.623411893844604
# --epoch: 1500/20000 | ECR: 48.72004 | IS: 0.25667 | WIS: 50.00000 | PDIS: 0.25667 | PDWIS: 0.06907 | DR: 546.29994 --
# Pred-> Constructive: 1903, Active: 0, Passive: 2158, None: 937
# Eval Time: 23.596807956695557
# --epoch: 1600/20000 | ECR: 48.08956 | IS: 13.56805 | WIS: 69.32607 | PDIS: 12.21571 | PDWIS: 3.98701 | DR: 745.76982 --
# Pred-> Constructive: 3094, Active: 1, Passive: 261, None: 1642
# Eval Time: 23.621410846710205
# --epoch: 1700/20000 | ECR: 50.93919 | IS: 25.89296 | WIS: 55.88863 | PDIS: 23.80650 | PDWIS: 5.52653 | DR: 719.58110 --
# Pred-> Constructive: 3444, Active: 41, Passive: 1365, None: 148
# Eval Time: 23.688005924224854
# --epoch: 1800/20000 | ECR: 46.99014 | IS: 0.29343 | WIS: 14.29000 | PDIS: 0.29343 | PDWIS: 0.12845 | DR: 674.66405 --
# Pred-> Constructive: 0, Active: 0, Passive: 3592, None: 1406
# Eval Time: 23.635552167892456
# --epoch: 1900/20000 | ECR: 47.56671 | IS: 29.55056 | WIS: 61.40212 | PDIS: 27.28122 | PDWIS: 6.37887 | DR: 699.44514 --
# Pred-> Constructive: 3342, Active: 0, Passive: 23, None: 1633
# Eval Time: 23.63030505180359
# --epoch: 2000/20000 | ECR: 51.35718 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.38047 | DR: 750.99978 --
# Pred-> Constructive: 3499, Active: 0, Passive: 0, None: 1499
# Eval Time: 23.612028121948242
# --epoch: 2100/20000 | ECR: 45.90552 | IS: 0.29343 | WIS: 14.29000 | PDIS: 0.29343 | PDWIS: 0.12845 | DR: 661.18901 --
# Pred-> Constructive: 0, Active: 0, Passive: 3231, None: 1767
# Eval Time: 23.705792903900146
# --epoch: 2200/20000 | ECR: 43.43003 | IS: 25.89296 | WIS: 58.48057 | PDIS: 23.80650 | PDWIS: 5.61776 | DR: 621.66578 --
# Pred-> Constructive: 3179, Active: 0, Passive: 0, None: 1819
# ...
# Eval Time: 33.49599623680115
# --epoch: 12800/20000 | ECR: 59.41932 | IS: 21.26589 | WIS: 68.89971 | PDIS: 19.47106 | PDWIS: 5.35632 | DR: 757.26577 --
# Pred-> Constructive: 1871, Active: 1896, Passive: 858, None: 373
# Eval Time: 26.408983945846558
# --epoch: 12900/20000 | ECR: 57.50935 | IS: 514.82366 | WIS: 63.04410 | PDIS: 347.91982 | PDWIS: 8.90626 | DR: 1481.00258 --
# Pred-> Constructive: 1855, Active: 1558, Passive: 875, None: 710
# Eval Time: 28.47223687171936
# --epoch: 13000/20000 | ECR: 54.60243 | IS: 56.16322 | WIS: 87.43732 | PDIS: 49.57352 | PDWIS: 16.70695 | DR: 602.01531 --
# Pred-> Constructive: 1426, Active: 1739, Passive: 1246, None: 587
# Eval Time: 28.30882716178894
# --epoch: 13100/20000 | ECR: 54.83539 | IS: 21.14618 | WIS: 65.51533 | PDIS: 19.36342 | PDWIS: 5.00442 | DR: 808.91257 --
# Pred-> Constructive: 2487, Active: 906, Passive: 981, None: 624
# Eval Time: 28.01829504966736
# --epoch: 13200/20000 | ECR: 55.93163 | IS: 20.18566 | WIS: 64.06788 | PDIS: 18.45459 | PDWIS: 5.31730 | DR: 751.16570 --
# Pred-> Constructive: 3296, Active: 576, Passive: 694, None: 432
# Eval Time: 29.18422293663025
# --epoch: 13300/20000 | ECR: 54.56626 | IS: 7.66557 | WIS: 54.79826 | PDIS: 7.33899 | PDWIS: 2.51905 | DR: 558.80269 --
# Pred-> Constructive: 1441, Active: 1132, Passive: 1594, None: 831
# Eval Time: 29.708364009857178
# --epoch: 13400/20000 | ECR: 56.08134 | IS: 14.14863 | WIS: 63.35983 | PDIS: 13.47562 | PDWIS: 3.75409 | DR: 703.00392 --
# Pred-> Constructive: 2584, Active: 1342, Passive: 356, None: 716
# Eval Time: 30.005738973617554
# --epoch: 13500/20000 | ECR: 56.53390 | IS: 30.55623 | WIS: 70.59872 | PDIS: 26.61418 | PDWIS: 9.27740 | DR: 646.85074 --
# Pred-> Constructive: 2314, Active: 1220, Passive: 803, None: 661
# Eval Time: 35.771682024002075
# --epoch: 13600/20000 | ECR: 58.98050 | IS: 31.64566 | WIS: 71.42157 | PDIS: 27.70361 | PDWIS: 7.39934 | DR: 769.10317 --
# Pred-> Constructive: 2418, Active: 1258, Passive: 592, None: 730
# Eval Time: 29.607964277267456
# --epoch: 13700/20000 | ECR: 60.71635 | IS: 13.03265 | WIS: 54.30503 | PDIS: 12.33426 | PDWIS: 2.36919 | DR: 958.33893 --
# Pred-> Constructive: 3239, Active: 797, Passive: 659, None: 303
# Eval Time: 34.82399010658264
# --epoch: 13800/20000 | ECR: 60.41463 | IS: 520.24094 | WIS: 63.10500 | PDIS: 351.63272 | PDWIS: 10.89322 | DR: 1317.22218 --
# Pred-> Constructive: 2590, Active: 1131, Passive: 481, None: 796
# Eval Time: 27.46520709991455
# --epoch: 13900/20000 | ECR: 56.88616 | IS: 18.07043 | WIS: 69.36197 | PDIS: 17.06208 | PDWIS: 4.87470 | DR: 657.07308 --
# Pred-> Constructive: 2140, Active: 1732, Passive: 384, None: 742
# Eval Time: 32.308135747909546
# --epoch: 14000/20000 | ECR: 57.53008 | IS: 21.03817 | WIS: 71.89886 | PDIS: 19.93587 | PDWIS: 5.88625 | DR: 782.88169 --
# Pred-> Constructive: 1428, Active: 1430, Passive: 1650, None: 490
# Eval Time: 25.472476959228516
# --epoch: 14100/20000 | ECR: 55.76248 | IS: 502.80322 | WIS: 62.53025 | PDIS: 337.31951 | PDWIS: 8.05991 | DR: 1248.02394 --
# Pred-> Constructive: 2231, Active: 1221, Passive: 684, None: 862
# Eval Time: 25.604175806045532
# --epoch: 14200/20000 | ECR: 56.25413 | IS: 15.72972 | WIS: 60.97811 | PDIS: 14.82164 | PDWIS: 4.04787 | DR: 681.01432 --
# Pred-> Constructive: 2492, Active: 1647, Passive: 558, None: 301
# Eval Time: 25.536245107650757
# --epoch: 14300/20000 | ECR: 55.80626 | IS: 18.50296 | WIS: 74.31706 | PDIS: 17.53700 | PDWIS: 4.98464 | DR: 661.32230 --
# Pred-> Constructive: 1762, Active: 2022, Passive: 492, None: 722
# Eval Time: 25.421221017837524
# --epoch: 14400/20000 | ECR: 55.68321 | IS: 529.64290 | WIS: 63.25097 | PDIS: 360.23557 | PDWIS: 11.24554 | DR: 1282.37557 --
# Pred-> Constructive: 2183, Active: 1713, Passive: 563, None: 539
# Eval Time: 25.411558151245117
# --epoch: 14500/20000 | ECR: 56.03754 | IS: 12.26272 | WIS: 61.64587 | PDIS: 11.77687 | PDWIS: 3.47609 | DR: 623.64593 --
# Pred-> Constructive: 2195, Active: 1413, Passive: 451, None: 939
# Eval Time: 25.08331608772278
# --epoch: 14600/20000 | ECR: 52.52457 | IS: 17.78799 | WIS: 70.17927 | PDIS: 16.31271 | PDWIS: 5.25903 | DR: 687.20335 --
# Pred-> Constructive: 2220, Active: 836, Passive: 1090, None: 852
# Eval Time: 25.418381214141846
# --epoch: 14700/20000 | ECR: 51.80958 | IS: 29.48039 | WIS: 74.28009 | PDIS: 25.76061 | PDWIS: 8.02946 | DR: 722.99336 --
# Pred-> Constructive: 1935, Active: 1657, Passive: 780, None: 626
# Eval Time: 29.922253847122192
# --epoch: 14800/20000 | ECR: 54.73208 | IS: 14.96686 | WIS: 57.44916 | PDIS: 14.17451 | PDWIS: 2.85483 | DR: 807.97172 --
# Pred-> Constructive: 2680, Active: 851, Passive: 766, None: 701
# Eval Time: 28.530904054641724
# --epoch: 14900/20000 | ECR: 58.38770 | IS: 25.30128 | WIS: 67.17123 | PDIS: 23.39777 | PDWIS: 6.61619 | DR: 785.16671 --
# Pred-> Constructive: 2559, Active: 1121, Passive: 1026, None: 292
# Eval Time: 25.788097858428955
# --epoch: 15000/20000 | ECR: 58.53519 | IS: 9.59822 | WIS: 59.83144 | PDIS: 9.16279 | PDWIS: 2.20427 | DR: 711.95606 --
# Pred-> Constructive: 2441, Active: 1010, Passive: 1537, None: 10
# Eval Time: 25.816694974899292
# --epoch: 15100/20000 | ECR: 57.53430 | IS: 32.04006 | WIS: 74.02703 | PDIS: 28.19882 | PDWIS: 8.92303 | DR: 714.99122 --
# Pred-> Constructive: 2414, Active: 1590, Passive: 633, None: 361
# Eval Time: 29.70760202407837
# --epoch: 15200/20000 | ECR: 58.62820 | IS: 14.08461 | WIS: 65.71695 | PDIS: 13.48647 | PDWIS: 4.15999 | DR: 599.31021 --
# Pred-> Constructive: 1937, Active: 1797, Passive: 666, None: 598
# Eval Time: 33.42647075653076
# --epoch: 15300/20000 | ECR: 61.99947 | IS: 14.52293 | WIS: 65.41197 | PDIS: 13.86979 | PDWIS: 4.05821 | DR: 669.73961 --
# Pred-> Constructive: 1894, Active: 1804, Passive: 1074, None: 226
# Eval Time: 36.40477180480957
# --epoch: 15400/20000 | ECR: 59.99939 | IS: 505.74277 | WIS: 62.49683 | PDIS: 340.19833 | PDWIS: 7.95438 | DR: 1328.63379 --
# Pred-> Constructive: 2026, Active: 1503, Passive: 965, None: 504
# Eval Time: 31.794782161712646
# --epoch: 15500/20000 | ECR: 59.16922 | IS: 22.80728 | WIS: 68.22048 | PDIS: 21.06019 | PDWIS: 6.71759 | DR: 789.92777 --
# Pred-> Constructive: 2574, Active: 819, Passive: 1268, None: 337
# Eval Time: 41.08029103279114
# --epoch: 15600/20000 | ECR: 58.76134 | IS: 39.62047 | WIS: 76.65367 | PDIS: 34.58710 | PDWIS: 14.38124 | DR: 663.01996 --
# Pred-> Constructive: 1615, Active: 1855, Passive: 1399, None: 129
# Eval Time: 29.231884956359863
# --epoch: 15700/20000 | ECR: 58.65438 | IS: 518.21207 | WIS: 63.06507 | PDIS: 349.76255 | PDWIS: 10.35920 | DR: 1331.41611 --
# Pred-> Constructive: 2609, Active: 1005, Passive: 1349, None: 35
# Eval Time: 37.53576898574829
# --epoch: 15800/20000 | ECR: 59.80920 | IS: 516.99022 | WIS: 62.97785 | PDIS: 349.50001 | PDWIS: 12.74411 | DR: 1300.62554 --
# Pred-> Constructive: 2508, Active: 971, Passive: 1329, None: 190
# Eval Time: 29.938652992248535
# --epoch: 15900/20000 | ECR: 56.62969 | IS: 21.52442 | WIS: 75.71932 | PDIS: 19.77540 | PDWIS: 10.54937 | DR: 568.32602 --
# Pred-> Constructive: 1667, Active: 1206, Passive: 1494, None: 631
# Eval Time: 33.878676891326904
# --epoch: 16000/20000 | ECR: 55.79101 | IS: 517.57039 | WIS: 62.92801 | PDIS: 349.12086 | PDWIS: 9.62683 | DR: 1219.23672 --
# Pred-> Constructive: 3221, Active: 765, Passive: 875, None: 137
# Eval Time: 31.35903525352478
# --epoch: 16100/20000 | ECR: 58.29347 | IS: 17.88467 | WIS: 64.36829 | PDIS: 16.36445 | PDWIS: 7.35370 | DR: 668.08076 --
# Pred-> Constructive: 2264, Active: 603, Passive: 1968, None: 163
# Eval Time: 26.019238710403442
# --epoch: 16200/20000 | ECR: 55.31383 | IS: 63.11536 | WIS: 79.05081 | PDIS: 52.03147 | PDWIS: 11.74327 | DR: 749.66597 --
# Pred-> Constructive: 2386, Active: 887, Passive: 1530, None: 195
# Eval Time: 25.817668914794922
# --epoch: 16300/20000 | ECR: 58.08501 | IS: 18.57217 | WIS: 64.46073 | PDIS: 17.04966 | PDWIS: 5.49099 | DR: 709.65621 --
# Pred-> Constructive: 3188, Active: 742, Passive: 938, None: 130
# Eval Time: 26.06474804878235
# --epoch: 16400/20000 | ECR: 58.02396 | IS: 17.08951 | WIS: 68.99560 | PDIS: 16.31721 | PDWIS: 4.78955 | DR: 599.89500 --
# Pred-> Constructive: 1096, Active: 1795, Passive: 2047, None: 60
# Eval Time: 26.00522208213806
# --epoch: 16500/20000 | ECR: 56.65546 | IS: 39.74740 | WIS: 79.05853 | PDIS: 34.76216 | PDWIS: 14.82089 | DR: 617.78867 --
# Pred-> Constructive: 1597, Active: 1528, Passive: 1758, None: 115
# Eval Time: 26.577862977981567
# --epoch: 16600/20000 | ECR: 56.41847 | IS: 515.62131 | WIS: 62.93408 | PDIS: 348.83852 | PDWIS: 13.43536 | DR: 1130.40044 --
# Pred-> Constructive: 2214, Active: 705, Passive: 1409, None: 670
# Eval Time: 26.09134793281555
# --epoch: 16700/20000 | ECR: 55.66631 | IS: 70.31382 | WIS: 80.46782 | PDIS: 57.28477 | PDWIS: 13.41708 | DR: 694.59957 --
# Pred-> Constructive: 1655, Active: 984, Passive: 1907, None: 452
# Eval Time: 25.67211890220642
# --epoch: 16800/20000 | ECR: 56.55562 | IS: 22.21127 | WIS: 66.95174 | PDIS: 20.27913 | PDWIS: 5.92402 | DR: 755.34680 --
# Pred-> Constructive: 2921, Active: 796, Passive: 1041, None: 240
# Eval Time: 25.669485807418823
# --epoch: 16900/20000 | ECR: 56.65214 | IS: 20.24367 | WIS: 73.19659 | PDIS: 18.66385 | PDWIS: 6.80435 | DR: 666.02209 --
# Pred-> Constructive: 2802, Active: 708, Passive: 1447, None: 41
# Eval Time: 25.78426432609558
# --epoch: 17000/20000 | ECR: 54.08116 | IS: 512.38377 | WIS: 62.98288 | PDIS: 345.53529 | PDWIS: 11.72549 | DR: 1158.79913 --
# Pred-> Constructive: 1645, Active: 1057, Passive: 1877, None: 419
# Eval Time: 25.538660049438477
# --epoch: 17100/20000 | ECR: 52.27037 | IS: 42.30287 | WIS: 77.05996 | PDIS: 36.98342 | PDWIS: 16.91055 | DR: 572.96607 --
# Pred-> Constructive: 1495, Active: 1189, Passive: 1674, None: 640
# Eval Time: 25.688615083694458
# --epoch: 17200/20000 | ECR: 54.96416 | IS: 19.80359 | WIS: 62.34729 | PDIS: 18.13956 | PDWIS: 4.83458 | DR: 740.51010 --
# Pred-> Constructive: 3103, Active: 849, Passive: 910, None: 136
# Eval Time: 25.571144819259644
# --epoch: 17300/20000 | ECR: 54.22693 | IS: 31.82663 | WIS: 72.99283 | PDIS: 27.39676 | PDWIS: 7.68574 | DR: 741.28983 --
# Pred-> Constructive: 2634, Active: 904, Passive: 1392, None: 68
# Eval Time: 25.723157167434692
# --epoch: 17400/20000 | ECR: 53.22667 | IS: 23.97447 | WIS: 77.19382 | PDIS: 21.42484 | PDWIS: 6.52223 | DR: 717.13617 --
# Pred-> Constructive: 2984, Active: 846, Passive: 1168, None: 0
# Eval Time: 28.538756132125854
# --epoch: 17500/20000 | ECR: 55.66548 | IS: 36.16566 | WIS: 78.11582 | PDIS: 31.56047 | PDWIS: 7.55671 | DR: 794.58241 --
# Pred-> Constructive: 3044, Active: 641, Passive: 1237, None: 76
# Eval Time: 28.315476894378662
# --epoch: 17600/20000 | ECR: 55.92407 | IS: 37.90475 | WIS: 80.31374 | PDIS: 32.96763 | PDWIS: 15.64734 | DR: 566.56916 --
# Pred-> Constructive: 2370, Active: 911, Passive: 1634, None: 83
# Eval Time: 26.216227054595947
# --epoch: 17700/20000 | ECR: 57.31545 | IS: 25.64616 | WIS: 72.93243 | PDIS: 23.05297 | PDWIS: 7.08945 | DR: 692.77649 --
# Pred-> Constructive: 2813, Active: 666, Passive: 1518, None: 1
# Eval Time: 25.823664903640747
# --epoch: 17800/20000 | ECR: 57.41546 | IS: 8.44325 | WIS: 55.75407 | PDIS: 8.11026 | PDWIS: 2.71421 | DR: 557.30361 --
# Pred-> Constructive: 1649, Active: 606, Passive: 2721, None: 22
# Eval Time: 25.77700424194336
# --epoch: 17900/20000 | ECR: 55.31365 | IS: 15.12578 | WIS: 66.40006 | PDIS: 13.72054 | PDWIS: 6.75241 | DR: 624.73495 --
# Pred-> Constructive: 1641, Active: 700, Passive: 2148, None: 509
# Eval Time: 25.62743878364563
# --epoch: 18000/20000 | ECR: 53.73435 | IS: 539.25892 | WIS: 63.72543 | PDIS: 368.14632 | PDWIS: 16.89667 | DR: 1137.65864 --
# Pred-> Constructive: 1708, Active: 875, Passive: 1831, None: 584
# Eval Time: 25.331538200378418
# --epoch: 18100/20000 | ECR: 58.22489 | IS: 48.01860 | WIS: 78.39936 | PDIS: 41.68306 | PDWIS: 12.57573 | DR: 726.21979 --
# Pred-> Constructive: 2221, Active: 1009, Passive: 1452, None: 316
# Eval Time: 28.04281210899353
# --epoch: 18200/20000 | ECR: 60.44859 | IS: 22.62494 | WIS: 71.22972 | PDIS: 20.74002 | PDWIS: 5.32596 | DR: 819.86546 --
# Pred-> Constructive: 3095, Active: 479, Passive: 943, None: 481
# Eval Time: 25.294002056121826
# --epoch: 18300/20000 | ECR: 54.88847 | IS: 19.58368 | WIS: 71.47356 | PDIS: 17.83061 | PDWIS: 7.22760 | DR: 621.63650 --
# Pred-> Constructive: 1674, Active: 954, Passive: 1399, None: 971
# Eval Time: 27.913958072662354
# --epoch: 18400/20000 | ECR: 54.67223 | IS: 15.01858 | WIS: 74.30143 | PDIS: 13.66908 | PDWIS: 5.19645 | DR: 671.07240 --
# Pred-> Constructive: 1679, Active: 1299, Passive: 1427, None: 593
# Eval Time: 27.673866033554077
# --epoch: 18500/20000 | ECR: 55.30736 | IS: 30.06148 | WIS: 78.07968 | PDIS: 27.03917 | PDWIS: 8.51023 | DR: 702.57070 --
# Pred-> Constructive: 2343, Active: 966, Passive: 1304, None: 385
# Eval Time: 28.453188180923462
# --epoch: 18600/20000 | ECR: 58.85729 | IS: 32.17564 | WIS: 73.52274 | PDIS: 28.94939 | PDWIS: 8.77869 | DR: 740.05546 --
# Pred-> Constructive: 3247, Active: 627, Passive: 1123, None: 1
# Eval Time: 25.37586784362793
# --epoch: 18700/20000 | ECR: 56.67944 | IS: 28.79640 | WIS: 78.45509 | PDIS: 25.82669 | PDWIS: 5.16498 | DR: 1046.77044 --
# Pred-> Constructive: 2502, Active: 1361, Passive: 1115, None: 20
# Eval Time: 25.584990978240967
# --epoch: 18800/20000 | ECR: 57.05598 | IS: 41.62005 | WIS: 83.52954 | PDIS: 35.83762 | PDWIS: 9.41801 | DR: 757.07404 --
# Pred-> Constructive: 2362, Active: 1136, Passive: 1500, None: 0
# Eval Time: 25.432597160339355
# --epoch: 18900/20000 | ECR: 54.40889 | IS: 41.11316 | WIS: 83.69792 | PDIS: 35.86322 | PDWIS: 11.96693 | DR: 650.50418 --
# Pred-> Constructive: 2047, Active: 1453, Passive: 1498, None: 0
# Eval Time: 25.41032385826111
# --epoch: 19000/20000 | ECR: 52.43790 | IS: 21.23099 | WIS: 80.50214 | PDIS: 19.48197 | PDWIS: 5.99115 | DR: 616.92493 --
# Pred-> Constructive: 1971, Active: 1474, Passive: 1543, None: 10
# Eval Time: 25.491639137268066
# --epoch: 19100/20000 | ECR: 50.29153 | IS: 15.81860 | WIS: 70.23276 | PDIS: 14.34916 | PDWIS: 7.92870 | DR: 529.64607 --
# Pred-> Constructive: 1525, Active: 1542, Passive: 1824, None: 107
# Eval Time: 25.440109968185425
# --epoch: 19200/20000 | ECR: 51.29136 | IS: 40.37062 | WIS: 83.71733 | PDIS: 35.29600 | PDWIS: 10.42531 | DR: 679.75084 --
# Pred-> Constructive: 2405, Active: 1185, Passive: 1408, None: 0
# Eval Time: 25.443215131759644
# --epoch: 19300/20000 | ECR: 53.96271 | IS: 51.38284 | WIS: 79.71630 | PDIS: 44.95586 | PDWIS: 12.89286 | DR: 703.10417 --
# Pred-> Constructive: 2749, Active: 1234, Passive: 1015, None: 0
# Eval Time: 27.135281085968018
# --epoch: 19400/20000 | ECR: 57.12900 | IS: 42.87273 | WIS: 78.92837 | PDIS: 36.98604 | PDWIS: 13.99456 | DR: 713.17159 --
# Pred-> Constructive: 3223, Active: 639, Passive: 1136, None: 0
# Eval Time: 27.27505898475647
# --epoch: 19500/20000 | ECR: 55.97935 | IS: 35.56111 | WIS: 76.70372 | PDIS: 31.33004 | PDWIS: 6.42354 | DR: 876.19141 --
# Pred-> Constructive: 2629, Active: 1261, Passive: 1099, None: 9
# Eval Time: 25.742442846298218
# --epoch: 19600/20000 | ECR: 53.07246 | IS: 31.63919 | WIS: 71.82304 | PDIS: 27.68542 | PDWIS: 4.58345 | DR: 990.86454 --
# Pred-> Constructive: 1368, Active: 2371, Passive: 1257, None: 2
# Eval Time: 25.917563915252686
# --epoch: 19700/20000 | ECR: 56.50227 | IS: 47.56460 | WIS: 78.89800 | PDIS: 42.00585 | PDWIS: 13.15154 | DR: 713.61291 --
# Pred-> Constructive: 2228, Active: 1706, Passive: 1062, None: 2
# Eval Time: 25.498204231262207
# --epoch: 19800/20000 | ECR: 53.32391 | IS: 30.62069 | WIS: 76.47322 | PDIS: 27.78802 | PDWIS: 6.52071 | DR: 812.48154 --
# Pred-> Constructive: 3223, Active: 557, Passive: 1218, None: 0
# Eval Time: 25.753206968307495
# --epoch: 19900/20000 | ECR: 54.95991 | IS: 27.77121 | WIS: 74.36194 | PDIS: 24.99870 | PDWIS: 7.39545 | DR: 737.39744 --
# Pred-> Constructive: 3271, Active: 626, Passive: 1072, None: 29
# Eval Time: 25.691134929656982
# --epoch: 20000/20000 | ECR: 58.66978 | IS: 47.88999 | WIS: 80.98942 | PDIS: 42.15344 | PDWIS: 10.91479 | DR: 772.19952 --
# Pred-> Constructive: 2466, Active: 1533, Passive: 994, None: 5
# True-> Constructive: 2009, Active: 2074, Passive: 445, None: 470
# Pred-> Constructive: 2466, Active: 1533, Passive: 994, None: 5
# -> True Reward: 54.63407/30.52030, Pred Reward: 58.66978/18.42337

# %%
# target = 'ECR'
# step = 1

# y = []
# for i in range(int(len(eval_df)/step)):
#     y.append(eval_df.loc[i*step:i*step+step, target].mean())

# plt.plot(range(len(y)), y)

# %% [markdown]
# # OTHER EXPERIMENTAL DETAILS

# %%
import pandas as pd
df = pd.read_pickle('../temp/df_all_norm_cluster.pkl')
df.groupby(['action']).count()

df['delayed_reward'] = pd.to_numeric(df['delayed_reward'])
df.groupby(['episode_id']).sum()[['delayed_reward']].describe()
# Out:
#        delayed_reward
# count      487.000000
# mean        54.634066
# std         30.551682
# min       -100.000000
# 25%         36.360000
# 50%         60.000000
# 75%         77.780000
# max        100.000000

# %%
df.loc[df['done']==True].describe()
# Out:
#           cluster  ns_cluster  action_proba  ns_act_0_proba  ns_act_1_proba  \
# count  487.000000       487.0    487.000000    4.870000e+02    4.870000e+02
# mean     2.088296         1.0      0.362423    9.000000e-02    9.000000e-02
# std      1.512093         0.0      0.114959    8.335235e-16    8.335235e-16
# min      0.000000         1.0      0.080000    9.000000e-02    9.000000e-02
# 25%      1.000000         1.0      0.390000    9.000000e-02    9.000000e-02
# 50%      3.000000         1.0      0.400000    9.000000e-02    9.000000e-02
# 75%      3.000000         1.0      0.420000    9.000000e-02    9.000000e-02
# max      4.000000         1.0      0.440000    9.000000e-02    9.000000e-02
#
#        ns_act_2_proba  ns_act_3_proba
# count    4.870000e+02    4.870000e+02
# mean     4.200000e-01    3.900000e-01
# std      3.723072e-15    4.112049e-15
# min      4.200000e-01    3.900000e-01
# 25%      4.200000e-01    3.900000e-01
# 50%      4.200000e-01    3.900000e-01
# 75%      4.200000e-01    3.900000e-01
# max      4.200000e-01    3.900000e-01

# %%
df['delayed_reward'].unique()
# Out:
# array([0, 30.0, 88.89, 85.71, 71.43, 62.5, 66.67, 45.45, 40.0, 42.86,
#        100.0, 44.44, -12.5, 83.33, 25.0, 72.73, 37.5, 57.14, 20.0, 28.57,
#        75.0, 33.33, 27.27, 22.22, 50.0, 80.0, 77.78, 87.5, 55.56, 60.0,
#        10.0, 12.5, 70.0, -66.67, 9.09, 90.0, 18.18, 81.82, 63.64, -22.22,
#        11.11, 54.55, 14.29, -9.09, -100.0, -50.0, -33.33, 41.67, 16.67,
#        36.36, -25.0], dtype=object)
